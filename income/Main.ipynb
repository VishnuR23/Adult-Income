# %%
import pandas as pd

# %%
df = pd.read_csv('adult.csv')

# %%
df
# Out:
#        age     workclass  fnlwgt     education  educational-num  \
# 0       25       Private  226802          11th                7
# 1       38       Private   89814       HS-grad                9
# 2       28     Local-gov  336951    Assoc-acdm               12
# 3       44       Private  160323  Some-college               10
# 4       18             ?  103497  Some-college               10
# ...    ...           ...     ...           ...              ...
# 48837   27       Private  257302    Assoc-acdm               12
# 48838   40       Private  154374       HS-grad                9
# 48839   58       Private  151910       HS-grad                9
# 48840   22       Private  201490       HS-grad                9
# 48841   52  Self-emp-inc  287927       HS-grad                9
#
#            marital-status         occupation relationship   race  gender  \
# 0           Never-married  Machine-op-inspct    Own-child  Black    Male
# 1      Married-civ-spouse    Farming-fishing      Husband  White    Male
# 2      Married-civ-spouse    Protective-serv      Husband  White    Male
# 3      Married-civ-spouse  Machine-op-inspct      Husband  Black    Male
# 4           Never-married                  ?    Own-child  White  Female
# ...                   ...                ...          ...    ...     ...
# 48837  Married-civ-spouse       Tech-support         Wife  White  Female
# 48838  Married-civ-spouse  Machine-op-inspct      Husband  White    Male
# 48839             Widowed       Adm-clerical    Unmarried  White  Female
# 48840       Never-married       Adm-clerical    Own-child  White    Male
# 48841  Married-civ-spouse    Exec-managerial         Wife  White  Female
#
#        capital-gain  capital-loss  hours-per-week native-country income
# 0                 0             0              40  United-States  <=50K
# 1                 0             0              50  United-States  <=50K
# 2                 0             0              40  United-States   >50K
# 3              7688             0              40  United-States   >50K
# 4                 0             0              30  United-States  <=50K
# ...             ...           ...             ...            ...    ...
# 48837             0             0              38  United-States  <=50K
# 48838             0             0              40  United-States   >50K
# 48839             0             0              40  United-States  <=50K
# 48840             0             0              20  United-States  <=50K
# 48841         15024             0              40  United-States   >50K
#
# [48842 rows x 15 columns]

# %%
df.education.value_counts()
# Out:
# education
# HS-grad         15784
# Some-college    10878
# Bachelors        8025
# Masters          2657
# Assoc-voc        2061
# 11th             1812
# Assoc-acdm       1601
# 10th             1389
# 7th-8th           955
# Prof-school       834
# 9th               756
# 12th              657
# Doctorate         594
# 5th-6th           509
# 1st-4th           247
# Preschool          83
# Name: count, dtype: int64

# %%
df.age.value_counts()
# Out:
# age
# 36    1348
# 35    1337
# 33    1335
# 23    1329
# 31    1325
#       ...
# 88       6
# 85       5
# 87       3
# 89       2
# 86       1
# Name: count, Length: 74, dtype: int64

# %%
df.occupation.value_counts()
# Out:
# occupation
# Prof-specialty       6172
# Craft-repair         6112
# Exec-managerial      6086
# Adm-clerical         5611
# Sales                5504
# Other-service        4923
# Machine-op-inspct    3022
# ?                    2809
# Transport-moving     2355
# Handlers-cleaners    2072
# Farming-fishing      1490
# Tech-support         1446
# Protective-serv       983
# Priv-house-serv       242
# Armed-Forces           15
# Name: count, dtype: int64

# %%
df = df.drop('education', axis = 1)
df = pd.concat([df.drop('occupation', axis = 1), pd.get_dummies(df.occupation).add_prefix('occupation_')], axis = 1)
df = pd.concat([df.drop('workclass', axis = 1), pd.get_dummies(df.workclass).add_prefix('workclass_')], axis = 1)
df = pd.concat([df.drop('marital-status', axis = 1), pd.get_dummies(df['marital-status']).add_prefix('marital-status_')], axis = 1)
df = pd.concat([df.drop('relationship', axis = 1), pd.get_dummies(df.relationship).add_prefix('relationship_')], axis = 1)
df = pd.concat([df.drop('race', axis = 1), pd.get_dummies(df.race).add_prefix('race_')], axis = 1)
df = pd.concat([df.drop('native-country', axis = 1), pd.get_dummies(df['native-country']).add_prefix('native-country_')], axis = 1)

# %%
df
# Out:
#        age  fnlwgt  educational-num  gender  capital-gain  capital-loss  \
# 0       25  226802                7    Male             0             0
# 1       38   89814                9    Male             0             0
# 2       28  336951               12    Male             0             0
# 3       44  160323               10    Male          7688             0
# 4       18  103497               10  Female             0             0
# ...    ...     ...              ...     ...           ...           ...
# 48837   27  257302               12  Female             0             0
# 48838   40  154374                9    Male             0             0
# 48839   58  151910                9  Female             0             0
# 48840   22  201490                9    Male             0             0
# 48841   52  287927                9  Female         15024             0
#
#        hours-per-week income  occupation_?  occupation_Adm-clerical  ...  \
# 0                  40  <=50K         False                    False  ...
# 1                  50  <=50K         False                    False  ...
# 2                  40   >50K         False                    False  ...
# 3                  40   >50K         False                    False  ...
# 4                  30  <=50K          True                    False  ...
# ...               ...    ...           ...                      ...  ...
# 48837              38  <=50K         False                    False  ...
# 48838              40   >50K         False                    False  ...
# 48839              40  <=50K         False                     True  ...
# 48840              20  <=50K         False                     True  ...
# 48841              40   >50K         False                    False  ...
#
#        native-country_Portugal  native-country_Puerto-Rico  \
# 0                        False                       False
# 1                        False                       False
# 2                        False                       False
# 3                        False                       False
# 4                        False                       False
# ...                        ...                         ...
# 48837                    False                       False
# 48838                    False                       False
# 48839                    False                       False
# 48840                    False                       False
# 48841                    False                       False
#
#        native-country_Scotland  native-country_South  native-country_Taiwan  \
# 0                        False                 False                  False
# 1                        False                 False                  False
# 2                        False                 False                  False
# 3                        False                 False                  False
# 4                        False                 False                  False
# ...                        ...                   ...                    ...
# 48837                    False                 False                  False
# 48838                    False                 False                  False
# 48839                    False                 False                  False
# 48840                    False                 False                  False
# 48841                    False                 False                  False
#
#        native-country_Thailand  native-country_Trinadad&Tobago  \
# 0                        False                           False
# 1                        False                           False
# 2                        False                           False
# 3                        False                           False
# 4                        False                           False
# ...                        ...                             ...
# 48837                    False                           False
# 48838                    False                           False
# 48839                    False                           False
# 48840                    False                           False
# 48841                    False                           False
#
#        native-country_United-States  native-country_Vietnam  \
# 0                              True                   False
# 1                              True                   False
# 2                              True                   False
# 3                              True                   False
# 4                              True                   False
# ...                             ...                     ...
# 48837                          True                   False
# 48838                          True                   False
# 48839                          True                   False
# 48840                          True                   False
# 48841                          True                   False
#
#        native-country_Yugoslavia
# 0                          False
# 1                          False
# 2                          False
# 3                          False
# 4                          False
# ...                          ...
# 48837                      False
# 48838                      False
# 48839                      False
# 48840                      False
# 48841                      False
#
# [48842 rows x 92 columns]

# %%
df['gender'] = df['gender'].apply(lambda x: 1 if x == 'Male' else 0)
df['income'] = df['income'].apply(lambda x: 1 if x == '>50K' else 0)

# %%
df
# Out:
#        age  fnlwgt  educational-num  gender  capital-gain  capital-loss  \
# 0       25  226802                7       1             0             0
# 1       38   89814                9       1             0             0
# 2       28  336951               12       1             0             0
# 3       44  160323               10       1          7688             0
# 4       18  103497               10       0             0             0
# ...    ...     ...              ...     ...           ...           ...
# 48837   27  257302               12       0             0             0
# 48838   40  154374                9       1             0             0
# 48839   58  151910                9       0             0             0
# 48840   22  201490                9       1             0             0
# 48841   52  287927                9       0         15024             0
#
#        hours-per-week  income  occupation_?  occupation_Adm-clerical  ...  \
# 0                  40       0         False                    False  ...
# 1                  50       0         False                    False  ...
# 2                  40       1         False                    False  ...
# 3                  40       1         False                    False  ...
# 4                  30       0          True                    False  ...
# ...               ...     ...           ...                      ...  ...
# 48837              38       0         False                    False  ...
# 48838              40       1         False                    False  ...
# 48839              40       0         False                     True  ...
# 48840              20       0         False                     True  ...
# 48841              40       1         False                    False  ...
#
#        native-country_Portugal  native-country_Puerto-Rico  \
# 0                        False                       False
# 1                        False                       False
# 2                        False                       False
# 3                        False                       False
# 4                        False                       False
# ...                        ...                         ...
# 48837                    False                       False
# 48838                    False                       False
# 48839                    False                       False
# 48840                    False                       False
# 48841                    False                       False
#
#        native-country_Scotland  native-country_South  native-country_Taiwan  \
# 0                        False                 False                  False
# 1                        False                 False                  False
# 2                        False                 False                  False
# 3                        False                 False                  False
# 4                        False                 False                  False
# ...                        ...                   ...                    ...
# 48837                    False                 False                  False
# 48838                    False                 False                  False
# 48839                    False                 False                  False
# 48840                    False                 False                  False
# 48841                    False                 False                  False
#
#        native-country_Thailand  native-country_Trinadad&Tobago  \
# 0                        False                           False
# 1                        False                           False
# 2                        False                           False
# 3                        False                           False
# 4                        False                           False
# ...                        ...                             ...
# 48837                    False                           False
# 48838                    False                           False
# 48839                    False                           False
# 48840                    False                           False
# 48841                    False                           False
#
#        native-country_United-States  native-country_Vietnam  \
# 0                              True                   False
# 1                              True                   False
# 2                              True                   False
# 3                              True                   False
# 4                              True                   False
# ...                             ...                     ...
# 48837                          True                   False
# 48838                          True                   False
# 48839                          True                   False
# 48840                          True                   False
# 48841                          True                   False
#
#        native-country_Yugoslavia
# 0                          False
# 1                          False
# 2                          False
# 3                          False
# 4                          False
# ...                          ...
# 48837                      False
# 48838                      False
# 48839                      False
# 48840                      False
# 48841                      False
#
# [48842 rows x 92 columns]

# %%
df.columns.values
# Out:
# array(['age', 'fnlwgt', 'educational-num', 'gender', 'capital-gain',
#        'capital-loss', 'hours-per-week', 'income', 'occupation_?',
#        'occupation_Adm-clerical', 'occupation_Armed-Forces',
#        'occupation_Craft-repair', 'occupation_Exec-managerial',
#        'occupation_Farming-fishing', 'occupation_Handlers-cleaners',
#        'occupation_Machine-op-inspct', 'occupation_Other-service',
#        'occupation_Priv-house-serv', 'occupation_Prof-specialty',
#        'occupation_Protective-serv', 'occupation_Sales',
#        'occupation_Tech-support', 'occupation_Transport-moving',
#        'workclass_?', 'workclass_Federal-gov', 'workclass_Local-gov',
#        'workclass_Never-worked', 'workclass_Private',
#        'workclass_Self-emp-inc', 'workclass_Self-emp-not-inc',
#        'workclass_State-gov', 'workclass_Without-pay',
#        'marital-status_Divorced', 'marital-status_Married-AF-spouse',
#        'marital-status_Married-civ-spouse',
#        'marital-status_Married-spouse-absent',
#        'marital-status_Never-married', 'marital-status_Separated',
#        'marital-status_Widowed', 'relationship_Husband',
#        'relationship_Not-in-family', 'relationship_Other-relative',
#        'relationship_Own-child', 'relationship_Unmarried',
#        'relationship_Wife', 'race_Amer-Indian-Eskimo',
#        'race_Asian-Pac-Islander', 'race_Black', 'race_Other',
#        'race_White', 'native-country_?', 'native-country_Cambodia',
#        'native-country_Canada', 'native-country_China',
#        'native-country_Columbia', 'native-country_Cuba',
#        'native-country_Dominican-Republic', 'native-country_Ecuador',
#        'native-country_El-Salvador', 'native-country_England',
#        'native-country_France', 'native-country_Germany',
#        'native-country_Greece', 'native-country_Guatemala',
#        'native-country_Haiti', 'native-country_Holand-Netherlands',
#        'native-country_Honduras', 'native-country_Hong',
#        'native-country_Hungary', 'native-country_India',
#        'native-country_Iran', 'native-country_Ireland',
#        'native-country_Italy', 'native-country_Jamaica',
#        'native-country_Japan', 'native-country_Laos',
#        'native-country_Mexico', 'native-country_Nicaragua',
#        'native-country_Outlying-US(Guam-USVI-etc)', 'native-country_Peru',
#        'native-country_Philippines', 'native-country_Poland',
#        'native-country_Portugal', 'native-country_Puerto-Rico',
#        'native-country_Scotland', 'native-country_South',
#        'native-country_Taiwan', 'native-country_Thailand',
#        'native-country_Trinadad&Tobago', 'native-country_United-States',
#        'native-country_Vietnam', 'native-country_Yugoslavia'],
#       dtype=object)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(10,12))
sns.heatmap(df.corr(), annot=False, cmap='coolwarm')
# Out:
# <Axes: >

# %%
df.corr()
# Out:
#                                      age    fnlwgt  educational-num    gender  \
# age                             1.000000 -0.076628         0.030940  0.088120
# fnlwgt                         -0.076628  1.000000        -0.038761  0.027739
# educational-num                 0.030940 -0.038761         1.000000  0.009328
# gender                          0.088120  0.027739         0.009328  1.000000
# capital-gain                    0.077229 -0.003706         0.125146  0.047094
# ...                                  ...       ...              ...       ...
# native-country_Thailand        -0.001766 -0.001512         0.007283 -0.007117
# native-country_Trinadad&Tobago  0.001056  0.004153        -0.010201 -0.009342
# native-country_United-States    0.011888 -0.070645         0.104210 -0.011167
# native-country_Vietnam         -0.012337 -0.007479        -0.007544 -0.001545
# native-country_Yugoslavia       0.002905  0.004699        -0.005798  0.005262
#
#                                 capital-gain  capital-loss  hours-per-week  \
# age                                 0.077229      0.056944        0.071558
# fnlwgt                             -0.003706     -0.004366       -0.013519
# educational-num                     0.125146      0.080972        0.143689
# gender                              0.047094      0.045480        0.228560
# capital-gain                        1.000000     -0.031441        0.082157
# ...                                      ...           ...             ...
# native-country_Thailand            -0.002781     -0.002338        0.008558
# native-country_Trinadad&Tobago     -0.003039      0.004028       -0.002911
# native-country_United-States        0.004191      0.009449        0.004390
# native-country_Vietnam             -0.002673     -0.000118       -0.008289
# native-country_Yugoslavia          -0.000474     -0.004713       -0.000359
#
#                                   income  occupation_?  \
# age                             0.230369      0.025683
# fnlwgt                         -0.006339     -0.005405
# educational-num                 0.332613     -0.080053
# gender                          0.214628     -0.063844
# capital-gain                    0.223013     -0.019157
# ...                                  ...           ...
# native-country_Thailand        -0.004219     -0.002575
# native-country_Trinadad&Tobago -0.009107     -0.002068
# native-country_United-States    0.032551      0.005546
# native-country_Vietnam         -0.015542     -0.004082
# native-country_Yugoslavia       0.005522     -0.005362
#
#                                 occupation_Adm-clerical  ...  \
# age                                           -0.038116  ...
# fnlwgt                                         0.007480  ...
# educational-num                                0.004142  ...
# gender                                        -0.260349  ...
# capital-gain                                  -0.029105  ...
# ...                                                 ...  ...
# native-country_Thailand                       -0.001157  ...
# native-country_Trinadad&Tobago                 0.007917  ...
# native-country_United-States                   0.022126  ...
# native-country_Vietnam                         0.010905  ...
# native-country_Yugoslavia                     -0.004860  ...
#
#                                 native-country_Portugal  \
# age                                            0.007016
# fnlwgt                                        -0.013577
# educational-num                               -0.047816
# gender                                         0.009649
# capital-gain                                  -0.004355
# ...                                                 ...
# native-country_Thailand                       -0.000919
# native-country_Trinadad&Tobago                -0.000872
# native-country_United-States                  -0.109626
# native-country_Vietnam                        -0.001557
# native-country_Yugoslavia                     -0.000804
#
#                                 native-country_Puerto-Rico  \
# age                                               0.005474
# fnlwgt                                            0.008708
# educational-num                                  -0.041776
# gender                                           -0.009940
# capital-gain                                     -0.006137
# ...                                                    ...
# native-country_Thailand                          -0.001525
# native-country_Trinadad&Tobago                   -0.001446
# native-country_United-States                     -0.181890
# native-country_Vietnam                           -0.002583
# native-country_Yugoslavia                        -0.001335
#
#                                 native-country_Scotland  native-country_South  \
# age                                            0.012281             -0.001942
# fnlwgt                                        -0.006523             -0.010342
# educational-num                                0.000907              0.012984
# gender                                        -0.002178             -0.005272
# capital-gain                                  -0.002317              0.003906
# ...                                                 ...                   ...
# native-country_Thailand                       -0.000514             -0.001204
# native-country_Trinadad&Tobago                -0.000488             -0.001143
# native-country_United-States                  -0.061346             -0.143695
# native-country_Vietnam                        -0.000871             -0.002040
# native-country_Yugoslavia                     -0.000450             -0.001054
#
#                                 native-country_Taiwan  \
# age                                         -0.011872
# fnlwgt                                      -0.001733
# educational-num                              0.045420
# gender                                       0.003041
# capital-gain                                 0.004260
# ...                                               ...
# native-country_Thailand                     -0.000905
# native-country_Trinadad&Tobago              -0.000859
# native-country_United-States                -0.107976
# native-country_Vietnam                      -0.001533
# native-country_Yugoslavia                   -0.000792
#
#                                 native-country_Thailand  \
# age                                           -0.001766
# fnlwgt                                        -0.001512
# educational-num                                0.007283
# gender                                        -0.007117
# capital-gain                                  -0.002781
# ...                                                 ...
# native-country_Thailand                        1.000000
# native-country_Trinadad&Tobago                -0.000583
# native-country_United-States                  -0.073329
# native-country_Vietnam                        -0.001041
# native-country_Yugoslavia                     -0.000538
#
#                                 native-country_Trinadad&Tobago  \
# age                                                   0.001056
# fnlwgt                                                0.004153
# educational-num                                      -0.010201
# gender                                               -0.009342
# capital-gain                                         -0.003039
# ...                                                        ...
# native-country_Thailand                              -0.000583
# native-country_Trinadad&Tobago                        1.000000
# native-country_United-States                         -0.069564
# native-country_Vietnam                               -0.000988
# native-country_Yugoslavia                            -0.000510
#
#                                 native-country_United-States  \
# age                                                 0.011888
# fnlwgt                                             -0.070645
# educational-num                                     0.104210
# gender                                             -0.011167
# capital-gain                                        0.004191
# ...                                                      ...
# native-country_Thailand                            -0.073329
# native-country_Trinadad&Tobago                     -0.069564
# native-country_United-States                        1.000000
# native-country_Vietnam                             -0.124226
# native-country_Yugoslavia                          -0.064202
#
#                                 native-country_Vietnam  \
# age                                          -0.012337
# fnlwgt                                       -0.007479
# educational-num                              -0.007544
# gender                                       -0.001545
# capital-gain                                 -0.002673
# ...                                                ...
# native-country_Thailand                      -0.001041
# native-country_Trinadad&Tobago               -0.000988
# native-country_United-States                 -0.124226
# native-country_Vietnam                        1.000000
# native-country_Yugoslavia                    -0.000912
#
#                                 native-country_Yugoslavia
# age                                              0.002905
# fnlwgt                                           0.004699
# educational-num                                 -0.005798
# gender                                           0.005262
# capital-gain                                    -0.000474
# ...                                                   ...
# native-country_Thailand                         -0.000538
# native-country_Trinadad&Tobago                  -0.000510
# native-country_United-States                    -0.064202
# native-country_Vietnam                          -0.000912
# native-country_Yugoslavia                        1.000000
#
# [92 rows x 92 columns]

# %%
correlations = df.corr()['income'].abs()
sorted_correlations = correlations.sort_values()
num_cols_to_drop = int(0.8 * len(df.columns))
cols_to_drop = sorted_correlations.iloc[:num_cols_to_drop].index
df_dropped = df.drop(cols_to_drop, axis = 1)
df_dropped
# Out:
#        age  educational-num  gender  capital-gain  capital-loss  \
# 0       25                7       1             0             0
# 1       38                9       1             0             0
# 2       28               12       1             0             0
# 3       44               10       1          7688             0
# 4       18               10       0             0             0
# ...    ...              ...     ...           ...           ...
# 48837   27               12       0             0             0
# 48838   40                9       1             0             0
# 48839   58                9       0             0             0
# 48840   22                9       1             0             0
# 48841   52                9       0         15024             0
#
#        hours-per-week  income  occupation_Exec-managerial  \
# 0                  40       0                       False
# 1                  50       0                       False
# 2                  40       1                       False
# 3                  40       1                       False
# 4                  30       0                       False
# ...               ...     ...                         ...
# 48837              38       0                       False
# 48838              40       1                       False
# 48839              40       0                       False
# 48840              20       0                       False
# 48841              40       1                        True
#
#        occupation_Other-service  occupation_Prof-specialty  \
# 0                         False                      False
# 1                         False                      False
# 2                         False                      False
# 3                         False                      False
# 4                         False                      False
# ...                         ...                        ...
# 48837                     False                      False
# 48838                     False                      False
# 48839                     False                      False
# 48840                     False                      False
# 48841                     False                      False
#
#        workclass_Self-emp-inc  marital-status_Divorced  \
# 0                       False                    False
# 1                       False                    False
# 2                       False                    False
# 3                       False                    False
# 4                       False                    False
# ...                       ...                      ...
# 48837                   False                    False
# 48838                   False                    False
# 48839                   False                    False
# 48840                   False                    False
# 48841                    True                    False
#
#        marital-status_Married-civ-spouse  marital-status_Never-married  \
# 0                                  False                          True
# 1                                   True                         False
# 2                                   True                         False
# 3                                   True                         False
# 4                                  False                          True
# ...                                  ...                           ...
# 48837                               True                         False
# 48838                               True                         False
# 48839                              False                         False
# 48840                              False                          True
# 48841                               True                         False
#
#        relationship_Husband  relationship_Not-in-family  \
# 0                     False                       False
# 1                      True                       False
# 2                      True                       False
# 3                      True                       False
# 4                     False                       False
# ...                     ...                         ...
# 48837                 False                       False
# 48838                  True                       False
# 48839                 False                       False
# 48840                 False                       False
# 48841                 False                       False
#
#        relationship_Own-child  relationship_Unmarried  relationship_Wife
# 0                        True                   False              False
# 1                       False                   False              False
# 2                       False                   False              False
# 3                       False                   False              False
# 4                        True                   False              False
# ...                       ...                     ...                ...
# 48837                   False                   False               True
# 48838                   False                   False              False
# 48839                   False                    True              False
# 48840                    True                   False              False
# 48841                   False                   False               True
#
# [48842 rows x 19 columns]

# %%
plt.figure(figsize=(15,10))
sns.heatmap(df_dropped.corr(), annot=True, cmap='coolwarm')
# Out:
# <Axes: >

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split

df = df.drop('fnlwgt', axis = 1)

# %%
train_df, test_df = train_test_split(df, test_size = 0.2)

# %%
train_df
# Out:
#        age  educational-num  gender  capital-gain  capital-loss  \
# 28586   30               10       1             0             0
# 28638   30                9       1             0             0
# 22088   17                8       1             0             0
# 6184    48               12       1             0             0
# 30002   31                9       0             0             0
# ...    ...              ...     ...           ...           ...
# 31686   49                9       1             0             0
# 25166   47               14       1             0             0
# 14791   71                9       1             0          1816
# 46476   31               10       1             0             0
# 39179   84                3       1             0             0
#
#        hours-per-week  income  occupation_?  occupation_Adm-clerical  \
# 28586              40       0         False                    False
# 28638              40       1         False                    False
# 22088              18       0         False                    False
# 6184               40       1         False                    False
# 30002              40       0         False                     True
# ...               ...     ...           ...                      ...
# 31686              40       0         False                    False
# 25166              38       1         False                    False
# 14791              40       0          True                    False
# 46476              40       0         False                    False
# 39179              20       0          True                    False
#
#        occupation_Armed-Forces  ...  native-country_Portugal  \
# 28586                    False  ...                    False
# 28638                    False  ...                    False
# 22088                    False  ...                    False
# 6184                     False  ...                    False
# 30002                    False  ...                    False
# ...                        ...  ...                      ...
# 31686                    False  ...                    False
# 25166                    False  ...                    False
# 14791                    False  ...                    False
# 46476                    False  ...                    False
# 39179                    False  ...                    False
#
#        native-country_Puerto-Rico  native-country_Scotland  \
# 28586                       False                    False
# 28638                       False                    False
# 22088                       False                    False
# 6184                        False                    False
# 30002                       False                    False
# ...                           ...                      ...
# 31686                       False                    False
# 25166                       False                    False
# 14791                       False                    False
# 46476                       False                    False
# 39179                       False                    False
#
#        native-country_South  native-country_Taiwan  native-country_Thailand  \
# 28586                 False                  False                    False
# 28638                 False                  False                    False
# 22088                 False                  False                    False
# 6184                  False                  False                    False
# 30002                 False                  False                    False
# ...                     ...                    ...                      ...
# 31686                 False                  False                    False
# 25166                 False                  False                    False
# 14791                 False                  False                    False
# 46476                 False                  False                    False
# 39179                 False                  False                    False
#
#        native-country_Trinadad&Tobago  native-country_United-States  \
# 28586                           False                          True
# 28638                           False                          True
# 22088                           False                          True
# 6184                            False                          True
# 30002                           False                          True
# ...                               ...                           ...
# 31686                           False                          True
# 25166                           False                          True
# 14791                           False                          True
# 46476                           False                         False
# 39179                           False                          True
#
#        native-country_Vietnam  native-country_Yugoslavia
# 28586                   False                      False
# 28638                   False                      False
# 22088                   False                      False
# 6184                    False                      False
# 30002                   False                      False
# ...                       ...                        ...
# 31686                   False                      False
# 25166                   False                      False
# 14791                   False                      False
# 46476                   False                      False
# 39179                   False                      False
#
# [39073 rows x 91 columns]

# %%
test_df
# Out:
#        age  educational-num  gender  capital-gain  capital-loss  \
# 37186   25               13       0             0             0
# 34420   44               10       1             0             0
# 5114    31               10       1             0             0
# 19231   27               13       1             0             0
# 27083   52               10       1             0             0
# ...    ...              ...     ...           ...           ...
# 45912   31               15       1             0             0
# 9168    23               10       1             0             0
# 16630   31               13       1             0             0
# 37938   69               10       1          9386             0
# 18123   38               13       0             0             0
#
#        hours-per-week  income  occupation_?  occupation_Adm-clerical  \
# 37186              40       0         False                    False
# 34420              40       0         False                    False
# 5114               50       1         False                    False
# 19231              42       1         False                    False
# 27083              40       0         False                    False
# ...               ...     ...           ...                      ...
# 45912              40       0         False                    False
# 9168               20       0         False                    False
# 16630              25       0         False                    False
# 37938              72       1         False                    False
# 18123              40       0         False                    False
#
#        occupation_Armed-Forces  ...  native-country_Portugal  \
# 37186                    False  ...                    False
# 34420                    False  ...                    False
# 5114                     False  ...                    False
# 19231                    False  ...                    False
# 27083                    False  ...                    False
# ...                        ...  ...                      ...
# 45912                    False  ...                    False
# 9168                     False  ...                    False
# 16630                    False  ...                    False
# 37938                    False  ...                    False
# 18123                    False  ...                    False
#
#        native-country_Puerto-Rico  native-country_Scotland  \
# 37186                       False                    False
# 34420                       False                    False
# 5114                        False                    False
# 19231                       False                    False
# 27083                       False                    False
# ...                           ...                      ...
# 45912                       False                    False
# 9168                        False                    False
# 16630                       False                    False
# 37938                       False                    False
# 18123                       False                    False
#
#        native-country_South  native-country_Taiwan  native-country_Thailand  \
# 37186                 False                  False                    False
# 34420                 False                  False                    False
# 5114                  False                  False                    False
# 19231                 False                  False                    False
# 27083                 False                  False                    False
# ...                     ...                    ...                      ...
# 45912                 False                  False                    False
# 9168                  False                  False                    False
# 16630                 False                  False                    False
# 37938                 False                  False                    False
# 18123                 False                  False                    False
#
#        native-country_Trinadad&Tobago  native-country_United-States  \
# 37186                           False                          True
# 34420                           False                          True
# 5114                            False                          True
# 19231                           False                          True
# 27083                           False                          True
# ...                               ...                           ...
# 45912                           False                         False
# 9168                            False                          True
# 16630                           False                          True
# 37938                           False                          True
# 18123                           False                          True
#
#        native-country_Vietnam  native-country_Yugoslavia
# 37186                   False                      False
# 34420                   False                      False
# 5114                    False                      False
# 19231                   False                      False
# 27083                   False                      False
# ...                       ...                        ...
# 45912                   False                      False
# 9168                    False                      False
# 16630                   False                      False
# 37938                   False                      False
# 18123                   False                      False
#
# [9769 rows x 91 columns]

# %%
train_x = train_df.drop('income', axis = 1)
train_y = train_df['income']

test_x = test_df.drop('income', axis = 1)
test_y = test_df['income']

# %%
forest = RandomForestClassifier()
forest.fit(train_x, train_y)
# Out:
# RandomForestClassifier()

# %%
forest.score(test_x, test_y)
# Out:
# 0.8507523799774798

# %%
forest.feature_importances_
# Out:
# array([2.29028822e-01, 1.30750663e-01, 1.37071509e-02, 1.04902005e-01,
#        3.77813363e-02, 1.14292894e-01, 1.74980504e-03, 4.97481631e-03,
#        4.76907765e-05, 6.01451668e-03, 1.95523472e-02, 4.57271521e-03,
#        3.64945966e-03, 4.32357627e-03, 8.23002199e-03, 2.19410495e-04,
#        1.75760734e-02, 2.63431479e-03, 6.16008134e-03, 4.54880018e-03,
#        4.18590431e-03, 1.66163442e-03, 4.95113853e-03, 5.39519163e-03,
#        1.61336770e-06, 9.36867963e-03, 5.96762129e-03, 8.14069680e-03,
#        4.25006490e-03, 1.23087943e-04, 8.08802423e-03, 3.55341550e-04,
#        7.05911458e-02, 1.07557109e-03, 2.92502469e-02, 2.22779098e-03,
#        1.73771321e-03, 4.79365743e-02, 1.15371526e-02, 1.70006163e-03,
#        7.39063148e-03, 5.51620323e-03, 1.01204118e-02, 1.33448487e-03,
#        3.07246945e-03, 4.79856633e-03, 9.06747329e-04, 6.20313213e-03,
#        2.74811243e-03, 3.18676569e-04, 1.47953439e-03, 5.96602190e-04,
#        2.64273122e-04, 8.36944824e-04, 2.85007311e-04, 1.21992590e-04,
#        2.72729097e-04, 1.03975905e-03, 3.16472382e-04, 1.06890647e-03,
#        5.01460205e-04, 1.21076651e-04, 1.84781940e-04, 0.00000000e+00,
#        7.20573250e-06, 1.75219487e-04, 1.48755061e-04, 9.69125900e-04,
#        4.95377508e-04, 3.54120132e-04, 7.96680794e-04, 4.27752096e-04,
#        5.84210176e-04, 1.11335387e-04, 2.21686087e-03, 1.28569434e-04,
#        2.49596618e-05, 1.26329097e-04, 1.08082972e-03, 5.44806667e-04,
#        4.33938189e-04, 5.78320178e-04, 9.18061881e-05, 5.24002542e-04,
#        2.61748712e-04, 9.23926019e-05, 1.77113977e-04, 6.27007622e-03,
#        3.28142189e-04, 2.89590256e-04])

# %%
forest.feature_names_in_
# Out:
# array(['age', 'educational-num', 'gender', 'capital-gain', 'capital-loss',
#        'hours-per-week', 'occupation_?', 'occupation_Adm-clerical',
#        'occupation_Armed-Forces', 'occupation_Craft-repair',
#        'occupation_Exec-managerial', 'occupation_Farming-fishing',
#        'occupation_Handlers-cleaners', 'occupation_Machine-op-inspct',
#        'occupation_Other-service', 'occupation_Priv-house-serv',
#        'occupation_Prof-specialty', 'occupation_Protective-serv',
#        'occupation_Sales', 'occupation_Tech-support',
#        'occupation_Transport-moving', 'workclass_?',
#        'workclass_Federal-gov', 'workclass_Local-gov',
#        'workclass_Never-worked', 'workclass_Private',
#        'workclass_Self-emp-inc', 'workclass_Self-emp-not-inc',
#        'workclass_State-gov', 'workclass_Without-pay',
#        'marital-status_Divorced', 'marital-status_Married-AF-spouse',
#        'marital-status_Married-civ-spouse',
#        'marital-status_Married-spouse-absent',
#        'marital-status_Never-married', 'marital-status_Separated',
#        'marital-status_Widowed', 'relationship_Husband',
#        'relationship_Not-in-family', 'relationship_Other-relative',
#        'relationship_Own-child', 'relationship_Unmarried',
#        'relationship_Wife', 'race_Amer-Indian-Eskimo',
#        'race_Asian-Pac-Islander', 'race_Black', 'race_Other',
#        'race_White', 'native-country_?', 'native-country_Cambodia',
#        'native-country_Canada', 'native-country_China',
#        'native-country_Columbia', 'native-country_Cuba',
#        'native-country_Dominican-Republic', 'native-country_Ecuador',
#        'native-country_El-Salvador', 'native-country_England',
#        'native-country_France', 'native-country_Germany',
#        'native-country_Greece', 'native-country_Guatemala',
#        'native-country_Haiti', 'native-country_Holand-Netherlands',
#        'native-country_Honduras', 'native-country_Hong',
#        'native-country_Hungary', 'native-country_India',
#        'native-country_Iran', 'native-country_Ireland',
#        'native-country_Italy', 'native-country_Jamaica',
#        'native-country_Japan', 'native-country_Laos',
#        'native-country_Mexico', 'native-country_Nicaragua',
#        'native-country_Outlying-US(Guam-USVI-etc)', 'native-country_Peru',
#        'native-country_Philippines', 'native-country_Poland',
#        'native-country_Portugal', 'native-country_Puerto-Rico',
#        'native-country_Scotland', 'native-country_South',
#        'native-country_Taiwan', 'native-country_Thailand',
#        'native-country_Trinadad&Tobago', 'native-country_United-States',
#        'native-country_Vietnam', 'native-country_Yugoslavia'],
#       dtype=object)

# %%
importances = dict(zip(forest.feature_names_in_, forest.feature_importances_))
importances = {k: v for k, v in sorted(importances.items(), key = lambda x: x[1], reverse=True)}

# %%
importances
# Out:
# {'age': np.float64(0.2290288215807432),
#  'educational-num': np.float64(0.13075066276099304),
#  'hours-per-week': np.float64(0.11429289390582298),
#  'capital-gain': np.float64(0.10490200546529352),
#  'marital-status_Married-civ-spouse': np.float64(0.07059114576190746),
#  'relationship_Husband': np.float64(0.047936574276604096),
#  'capital-loss': np.float64(0.03778133632298836),
#  'marital-status_Never-married': np.float64(0.029250246902904672),
#  'occupation_Exec-managerial': np.float64(0.019552347199037735),
#  'occupation_Prof-specialty': np.float64(0.01757607344837122),
#  'gender': np.float64(0.013707150910056897),
#  'relationship_Not-in-family': np.float64(0.011537152555523369),
#  'relationship_Wife': np.float64(0.010120411807001899),
#  'workclass_Private': np.float64(0.009368679633472278),
#  'occupation_Other-service': np.float64(0.008230021994453933),
#  'workclass_Self-emp-not-inc': np.float64(0.008140696800026848),
#  'marital-status_Divorced': np.float64(0.008088024232708128),
#  'relationship_Own-child': np.float64(0.007390631478197235),
#  'native-country_United-States': np.float64(0.006270076216976955),
#  'race_White': np.float64(0.006203132129523268),
#  'occupation_Sales': np.float64(0.006160081344112111),
#  'occupation_Craft-repair': np.float64(0.006014516684764412),
#  'workclass_Self-emp-inc': np.float64(0.005967621293425926),
#  'relationship_Unmarried': np.float64(0.005516203232368388),
#  'workclass_Local-gov': np.float64(0.0053951916341536165),
#  'occupation_Adm-clerical': np.float64(0.004974816313257258),
#  'workclass_Federal-gov': np.float64(0.0049511385312742875),
#  'race_Black': np.float64(0.004798566325563427),
#  'occupation_Farming-fishing': np.float64(0.004572715212652542),
#  'occupation_Tech-support': np.float64(0.00454880018264962),
#  'occupation_Machine-op-inspct': np.float64(0.0043235762684043656),
#  'workclass_State-gov': np.float64(0.004250064900570162),
#  'occupation_Transport-moving': np.float64(0.004185904314789555),
#  'occupation_Handlers-cleaners': np.float64(0.0036494596647604067),
#  'race_Asian-Pac-Islander': np.float64(0.003072469451437215),
#  'native-country_?': np.float64(0.002748112430481071),
#  'occupation_Protective-serv': np.float64(0.0026343147927329657),
#  'marital-status_Separated': np.float64(0.0022277909806218354),
#  'native-country_Mexico': np.float64(0.0022168608746593846),
#  'occupation_?': np.float64(0.0017498050407145458),
#  'marital-status_Widowed': np.float64(0.0017377132054169134),
#  'relationship_Other-relative': np.float64(0.0017000616276700228),
#  'workclass_?': np.float64(0.0016616344165438553),
#  'native-country_Canada': np.float64(0.001479534389369352),
#  'race_Amer-Indian-Eskimo': np.float64(0.0013344848662385817),
#  'native-country_Philippines': np.float64(0.0010808297220829155),
#  'marital-status_Married-spouse-absent': np.float64(0.0010755710940915607),
#  'native-country_Germany': np.float64(0.001068906467880805),
#  'native-country_England': np.float64(0.0010397590479224517),
#  'native-country_India': np.float64(0.0009691259004877241),
#  'race_Other': np.float64(0.000906747328608329),
#  'native-country_Cuba': np.float64(0.0008369448241956678),
#  'native-country_Italy': np.float64(0.000796680794206413),
#  'native-country_China': np.float64(0.0005966021895866061),
#  'native-country_Japan': np.float64(0.0005842101756207455),
#  'native-country_Puerto-Rico': np.float64(0.0005783201778429772),
#  'native-country_Poland': np.float64(0.0005448066668317101),
#  'native-country_South': np.float64(0.0005240025417015751),
#  'native-country_Greece': np.float64(0.000501460204623225),
#  'native-country_Iran': np.float64(0.0004953775079097479),
#  'native-country_Portugal': np.float64(0.00043393818949492125),
#  'native-country_Jamaica': np.float64(0.00042775209562684725),
#  'marital-status_Married-AF-spouse': np.float64(0.00035534155048624373),
#  'native-country_Ireland': np.float64(0.00035412013175197834),
#  'native-country_Vietnam': np.float64(0.0003281421888629213),
#  'native-country_Cambodia': np.float64(0.0003186765686998414),
#  'native-country_France': np.float64(0.0003164723817834588),
#  'native-country_Yugoslavia': np.float64(0.00028959025578207726),
#  'native-country_Dominican-Republic': np.float64(0.0002850073109031223),
#  'native-country_El-Salvador': np.float64(0.00027272909744787245),
#  'native-country_Columbia': np.float64(0.0002642731220948286),
#  'native-country_Taiwan': np.float64(0.0002617487122677128),
#  'occupation_Priv-house-serv': np.float64(0.000219410494975791),
#  'native-country_Haiti': np.float64(0.00018478194034806327),
#  'native-country_Trinadad&Tobago': np.float64(0.00017711397677397527),
#  'native-country_Hong': np.float64(0.00017521948690149916),
#  'native-country_Hungary': np.float64(0.0001487550607606642),
#  'native-country_Nicaragua': np.float64(0.00012856943387873197),
#  'native-country_Peru': np.float64(0.00012632909707086258),
#  'workclass_Without-pay': np.float64(0.00012308794254730878),
#  'native-country_Ecuador': np.float64(0.00012199259002298215),
#  'native-country_Guatemala': np.float64(0.00012107665085273327),
#  'native-country_Laos': np.float64(0.00011133538732574006),
#  'native-country_Thailand': np.float64(9.239260190390152e-05),
#  'native-country_Scotland': np.float64(9.180618814676275e-05),
#  'occupation_Armed-Forces': np.float64(4.769077646394579e-05),
#  'native-country_Outlying-US(Guam-USVI-etc)': np.float64(2.4959661796262393e-05),
#  'native-country_Honduras': np.float64(7.205732498570398e-06),
#  'workclass_Never-worked': np.float64(1.613367699076951e-06),
#  'native-country_Holand-Netherlands': np.float64(0.0)}

# %%
from sklearn.model_selection import GridSearchCV
param_grid = {
    'n_estimators': [50, 100, 250],
    'max_depth': [5, 10, 20, None],
    'min_samples_split': [2, 4],
    'max_features': ['sqrt', 'log2']
}

grid_search = GridSearchCV(estimator=RandomForestClassifier(),
                            param_grid=param_grid, verbose=10)

# %%
grid_search.fit(train_x, train_y)
# Out:
# Fitting 5 folds for each of 48 candidates, totalling 240 fits
# [CV 1/5; 1/48] START max_depth=5, max_features=sqrt, min_samples_split=2, n_estimators=50
# [CV 1/5; 1/48] END max_depth=5, max_features=sqrt, min_samples_split=2, n_estimators=50;, score=0.840 total time=   0.4s
# [CV 2/5; 1/48] START max_depth=5, max_features=sqrt, min_samples_split=2, n_estimators=50
# [CV 2/5; 1/48] END max_depth=5, max_features=sqrt, min_samples_split=2, n_estimators=50;, score=0.837 total time=   0.3s
# [CV 3/5; 1/48] START max_depth=5, max_features=sqrt, min_samples_split=2, n_estimators=50
# [CV 3/5; 1/48] END max_depth=5, max_features=sqrt, min_samples_split=2, n_estimators=50;, score=0.830 total time=   0.3s
# [CV 4/5; 1/48] START max_depth=5, max_features=sqrt, min_samples_split=2, n_estimators=50
# [CV 4/5; 1/48] END max_depth=5, max_features=sqrt, min_samples_split=2, n_estimators=50;, score=0.837 total time=   0.4s
# [CV 5/5; 1/48] START max_depth=5, max_features=sqrt, min_samples_split=2, n_estimators=50
# [CV 5/5; 1/48] END max_depth=5, max_features=sqrt, min_samples_split=2, n_estimators=50;, score=0.838 total time=   0.4s
# [CV 1/5; 2/48] START max_depth=5, max_features=sqrt, min_samples_split=2, n_estimators=100
# [CV 1/5; 2/48] END max_depth=5, max_features=sqrt, min_samples_split=2, n_estimators=100;, score=0.847 total time=   0.6s
# [CV 2/5; 2/48] START max_depth=5, max_features=sqrt, min_samples_split=2, n_estimators=100
# [CV 2/5; 2/48] END max_depth=5, max_features=sqrt, min_samples_split=2, n_estimators=100;, score=0.835 total time=   0.6s
# [CV 3/5; 2/48] START max_depth=5, max_features=sqrt, min_samples_split=2, n_estimators=100
# [CV 3/5; 2/48] END max_depth=5, max_features=sqrt, min_samples_split=2, n_estimators=100;, score=0.837 total time=   0.5s
# [CV 4/5; 2/48] START max_depth=5, max_features=sqrt, min_samples_split=2, n_estimators=100
# [CV 4/5; 2/48] END max_depth=5, max_features=sqrt, min_samples_split=2, n_estimators=100;, score=0.835 total time=   0.6s
# [CV 5/5; 2/48] START max_depth=5, max_features=sqrt, min_samples_split=2, n_estimators=100
# [CV 5/5; 2/48] END max_depth=5, max_features=sqrt, min_samples_split=2, n_estimators=100;, score=0.830 total time=   0.6s
# [CV 1/5; 3/48] START max_depth=5, max_features=sqrt, min_samples_split=2, n_estimators=250
# [CV 1/5; 3/48] END max_depth=5, max_features=sqrt, min_samples_split=2, n_estimators=250;, score=0.841 total time=   1.4s
# [CV 2/5; 3/48] START max_depth=5, max_features=sqrt, min_samples_split=2, n_estimators=250
# [CV 2/5; 3/48] END max_depth=5, max_features=sqrt, min_samples_split=2, n_estimators=250;, score=0.836 total time=   1.5s
# [CV 3/5; 3/48] START max_depth=5, max_features=sqrt, min_samples_split=2, n_estimators=250
# [CV 3/5; 3/48] END max_depth=5, max_features=sqrt, min_samples_split=2, n_estimators=250;, score=0.838 total time=   1.4s
# [CV 4/5; 3/48] START max_depth=5, max_features=sqrt, min_samples_split=2, n_estimators=250
# [CV 4/5; 3/48] END max_depth=5, max_features=sqrt, min_samples_split=2, n_estimators=250;, score=0.834 total time=   1.4s
# [CV 5/5; 3/48] START max_depth=5, max_features=sqrt, min_samples_split=2, n_estimators=250
# [CV 5/5; 3/48] END max_depth=5, max_features=sqrt, min_samples_split=2, n_estimators=250;, score=0.837 total time=   1.4s
# [CV 1/5; 4/48] START max_depth=5, max_features=sqrt, min_samples_split=4, n_estimators=50
# [CV 1/5; 4/48] END max_depth=5, max_features=sqrt, min_samples_split=4, n_estimators=50;, score=0.845 total time=   0.3s
# [CV 2/5; 4/48] START max_depth=5, max_features=sqrt, min_samples_split=4, n_estimators=50
# [CV 2/5; 4/48] END max_depth=5, max_features=sqrt, min_samples_split=4, n_estimators=50;, score=0.834 total time=   0.3s
# [CV 3/5; 4/48] START max_depth=5, max_features=sqrt, min_samples_split=4, n_estimators=50
# [CV 3/5; 4/48] END max_depth=5, max_features=sqrt, min_samples_split=4, n_estimators=50;, score=0.838 total time=   0.3s
# [CV 4/5; 4/48] START max_depth=5, max_features=sqrt, min_samples_split=4, n_estimators=50
# [CV 4/5; 4/48] END max_depth=5, max_features=sqrt, min_samples_split=4, n_estimators=50;, score=0.837 total time=   0.3s
# [CV 5/5; 4/48] START max_depth=5, max_features=sqrt, min_samples_split=4, n_estimators=50
# [CV 5/5; 4/48] END max_depth=5, max_features=sqrt, min_samples_split=4, n_estimators=50;, score=0.837 total time=   0.3s
# [CV 1/5; 5/48] START max_depth=5, max_features=sqrt, min_samples_split=4, n_estimators=100
# [CV 1/5; 5/48] END max_depth=5, max_features=sqrt, min_samples_split=4, n_estimators=100;, score=0.842 total time=   0.6s
# [CV 2/5; 5/48] START max_depth=5, max_features=sqrt, min_samples_split=4, n_estimators=100
# [CV 2/5; 5/48] END max_depth=5, max_features=sqrt, min_samples_split=4, n_estimators=100;, score=0.836 total time=   0.6s
# [CV 3/5; 5/48] START max_depth=5, max_features=sqrt, min_samples_split=4, n_estimators=100
# [CV 3/5; 5/48] END max_depth=5, max_features=sqrt, min_samples_split=4, n_estimators=100;, score=0.839 total time=   0.6s
# [CV 4/5; 5/48] START max_depth=5, max_features=sqrt, min_samples_split=4, n_estimators=100
# [CV 4/5; 5/48] END max_depth=5, max_features=sqrt, min_samples_split=4, n_estimators=100;, score=0.831 total time=   0.6s
# [CV 5/5; 5/48] START max_depth=5, max_features=sqrt, min_samples_split=4, n_estimators=100
# [CV 5/5; 5/48] END max_depth=5, max_features=sqrt, min_samples_split=4, n_estimators=100;, score=0.842 total time=   0.6s
# [CV 1/5; 6/48] START max_depth=5, max_features=sqrt, min_samples_split=4, n_estimators=250
# [CV 1/5; 6/48] END max_depth=5, max_features=sqrt, min_samples_split=4, n_estimators=250;, score=0.844 total time=   1.4s
# [CV 2/5; 6/48] START max_depth=5, max_features=sqrt, min_samples_split=4, n_estimators=250
# [CV 2/5; 6/48] END max_depth=5, max_features=sqrt, min_samples_split=4, n_estimators=250;, score=0.838 total time=   1.4s
# [CV 3/5; 6/48] START max_depth=5, max_features=sqrt, min_samples_split=4, n_estimators=250
# [CV 3/5; 6/48] END max_depth=5, max_features=sqrt, min_samples_split=4, n_estimators=250;, score=0.839 total time=   1.5s
# [CV 4/5; 6/48] START max_depth=5, max_features=sqrt, min_samples_split=4, n_estimators=250
# [CV 4/5; 6/48] END max_depth=5, max_features=sqrt, min_samples_split=4, n_estimators=250;, score=0.834 total time=   1.3s
# [CV 5/5; 6/48] START max_depth=5, max_features=sqrt, min_samples_split=4, n_estimators=250
# [CV 5/5; 6/48] END max_depth=5, max_features=sqrt, min_samples_split=4, n_estimators=250;, score=0.839 total time=   1.4s
# [CV 1/5; 7/48] START max_depth=5, max_features=log2, min_samples_split=2, n_estimators=50
# [CV 1/5; 7/48] END max_depth=5, max_features=log2, min_samples_split=2, n_estimators=50;, score=0.822 total time=   0.2s
# [CV 2/5; 7/48] START max_depth=5, max_features=log2, min_samples_split=2, n_estimators=50
# [CV 2/5; 7/48] END max_depth=5, max_features=log2, min_samples_split=2, n_estimators=50;, score=0.811 total time=   0.2s
# [CV 3/5; 7/48] START max_depth=5, max_features=log2, min_samples_split=2, n_estimators=50
# [CV 3/5; 7/48] END max_depth=5, max_features=log2, min_samples_split=2, n_estimators=50;, score=0.817 total time=   0.2s
# [CV 4/5; 7/48] START max_depth=5, max_features=log2, min_samples_split=2, n_estimators=50
# [CV 4/5; 7/48] END max_depth=5, max_features=log2, min_samples_split=2, n_estimators=50;, score=0.814 total time=   0.3s
# [CV 5/5; 7/48] START max_depth=5, max_features=log2, min_samples_split=2, n_estimators=50
# [CV 5/5; 7/48] END max_depth=5, max_features=log2, min_samples_split=2, n_estimators=50;, score=0.814 total time=   0.2s
# [CV 1/5; 8/48] START max_depth=5, max_features=log2, min_samples_split=2, n_estimators=100
# [CV 1/5; 8/48] END max_depth=5, max_features=log2, min_samples_split=2, n_estimators=100;, score=0.818 total time=   0.5s
# [CV 2/5; 8/48] START max_depth=5, max_features=log2, min_samples_split=2, n_estimators=100
# [CV 2/5; 8/48] END max_depth=5, max_features=log2, min_samples_split=2, n_estimators=100;, score=0.807 total time=   0.5s
# [CV 3/5; 8/48] START max_depth=5, max_features=log2, min_samples_split=2, n_estimators=100
# [CV 3/5; 8/48] END max_depth=5, max_features=log2, min_samples_split=2, n_estimators=100;, score=0.818 total time=   0.5s
# [CV 4/5; 8/48] START max_depth=5, max_features=log2, min_samples_split=2, n_estimators=100
# [CV 4/5; 8/48] END max_depth=5, max_features=log2, min_samples_split=2, n_estimators=100;, score=0.815 total time=   0.5s
# [CV 5/5; 8/48] START max_depth=5, max_features=log2, min_samples_split=2, n_estimators=100
# [CV 5/5; 8/48] END max_depth=5, max_features=log2, min_samples_split=2, n_estimators=100;, score=0.816 total time=   0.5s
# [CV 1/5; 9/48] START max_depth=5, max_features=log2, min_samples_split=2, n_estimators=250
# [CV 1/5; 9/48] END max_depth=5, max_features=log2, min_samples_split=2, n_estimators=250;, score=0.816 total time=   1.2s
# [CV 2/5; 9/48] START max_depth=5, max_features=log2, min_samples_split=2, n_estimators=250
# [CV 2/5; 9/48] END max_depth=5, max_features=log2, min_samples_split=2, n_estimators=250;, score=0.805 total time=   1.2s
# [CV 3/5; 9/48] START max_depth=5, max_features=log2, min_samples_split=2, n_estimators=250
# [CV 3/5; 9/48] END max_depth=5, max_features=log2, min_samples_split=2, n_estimators=250;, score=0.813 total time=   1.1s
# [CV 4/5; 9/48] START max_depth=5, max_features=log2, min_samples_split=2, n_estimators=250
# [CV 4/5; 9/48] END max_depth=5, max_features=log2, min_samples_split=2, n_estimators=250;, score=0.818 total time=   1.1s
# [CV 5/5; 9/48] START max_depth=5, max_features=log2, min_samples_split=2, n_estimators=250
# [CV 5/5; 9/48] END max_depth=5, max_features=log2, min_samples_split=2, n_estimators=250;, score=0.820 total time=   1.1s
# [CV 1/5; 10/48] START max_depth=5, max_features=log2, min_samples_split=4, n_estimators=50
# [CV 1/5; 10/48] END max_depth=5, max_features=log2, min_samples_split=4, n_estimators=50;, score=0.817 total time=   0.2s
# [CV 2/5; 10/48] START max_depth=5, max_features=log2, min_samples_split=4, n_estimators=50
# [CV 2/5; 10/48] END max_depth=5, max_features=log2, min_samples_split=4, n_estimators=50;, score=0.822 total time=   0.2s
# [CV 3/5; 10/48] START max_depth=5, max_features=log2, min_samples_split=4, n_estimators=50
# [CV 3/5; 10/48] END max_depth=5, max_features=log2, min_samples_split=4, n_estimators=50;, score=0.827 total time=   0.2s
# [CV 4/5; 10/48] START max_depth=5, max_features=log2, min_samples_split=4, n_estimators=50
# [CV 4/5; 10/48] END max_depth=5, max_features=log2, min_samples_split=4, n_estimators=50;, score=0.810 total time=   0.2s
# [CV 5/5; 10/48] START max_depth=5, max_features=log2, min_samples_split=4, n_estimators=50
# [CV 5/5; 10/48] END max_depth=5, max_features=log2, min_samples_split=4, n_estimators=50;, score=0.807 total time=   0.3s
# [CV 1/5; 11/48] START max_depth=5, max_features=log2, min_samples_split=4, n_estimators=100
# [CV 1/5; 11/48] END max_depth=5, max_features=log2, min_samples_split=4, n_estimators=100;, score=0.822 total time=   0.5s
# [CV 2/5; 11/48] START max_depth=5, max_features=log2, min_samples_split=4, n_estimators=100
# [CV 2/5; 11/48] END max_depth=5, max_features=log2, min_samples_split=4, n_estimators=100;, score=0.814 total time=   0.5s
# [CV 3/5; 11/48] START max_depth=5, max_features=log2, min_samples_split=4, n_estimators=100
# [CV 3/5; 11/48] END max_depth=5, max_features=log2, min_samples_split=4, n_estimators=100;, score=0.816 total time=   0.4s
# [CV 4/5; 11/48] START max_depth=5, max_features=log2, min_samples_split=4, n_estimators=100
# [CV 4/5; 11/48] END max_depth=5, max_features=log2, min_samples_split=4, n_estimators=100;, score=0.818 total time=   0.4s
# [CV 5/5; 11/48] START max_depth=5, max_features=log2, min_samples_split=4, n_estimators=100
# [CV 5/5; 11/48] END max_depth=5, max_features=log2, min_samples_split=4, n_estimators=100;, score=0.803 total time=   0.5s
# [CV 1/5; 12/48] START max_depth=5, max_features=log2, min_samples_split=4, n_estimators=250
# [CV 1/5; 12/48] END max_depth=5, max_features=log2, min_samples_split=4, n_estimators=250;, score=0.819 total time=   1.2s
# [CV 2/5; 12/48] START max_depth=5, max_features=log2, min_samples_split=4, n_estimators=250
# [CV 2/5; 12/48] END max_depth=5, max_features=log2, min_samples_split=4, n_estimators=250;, score=0.813 total time=   1.1s
# [CV 3/5; 12/48] START max_depth=5, max_features=log2, min_samples_split=4, n_estimators=250
# [CV 3/5; 12/48] END max_depth=5, max_features=log2, min_samples_split=4, n_estimators=250;, score=0.811 total time=   1.2s
# [CV 4/5; 12/48] START max_depth=5, max_features=log2, min_samples_split=4, n_estimators=250
# [CV 4/5; 12/48] END max_depth=5, max_features=log2, min_samples_split=4, n_estimators=250;, score=0.817 total time=   1.1s
# [CV 5/5; 12/48] START max_depth=5, max_features=log2, min_samples_split=4, n_estimators=250
# [CV 5/5; 12/48] END max_depth=5, max_features=log2, min_samples_split=4, n_estimators=250;, score=0.819 total time=   1.2s
# [CV 1/5; 13/48] START max_depth=10, max_features=sqrt, min_samples_split=2, n_estimators=50
# [CV 1/5; 13/48] END max_depth=10, max_features=sqrt, min_samples_split=2, n_estimators=50;, score=0.862 total time=   0.4s
# [CV 2/5; 13/48] START max_depth=10, max_features=sqrt, min_samples_split=2, n_estimators=50
# [CV 2/5; 13/48] END max_depth=10, max_features=sqrt, min_samples_split=2, n_estimators=50;, score=0.861 total time=   0.4s
# [CV 3/5; 13/48] START max_depth=10, max_features=sqrt, min_samples_split=2, n_estimators=50
# [CV 3/5; 13/48] END max_depth=10, max_features=sqrt, min_samples_split=2, n_estimators=50;, score=0.859 total time=   0.4s
# [CV 4/5; 13/48] START max_depth=10, max_features=sqrt, min_samples_split=2, n_estimators=50
# [CV 4/5; 13/48] END max_depth=10, max_features=sqrt, min_samples_split=2, n_estimators=50;, score=0.854 total time=   0.4s
# [CV 5/5; 13/48] START max_depth=10, max_features=sqrt, min_samples_split=2, n_estimators=50
# [CV 5/5; 13/48] END max_depth=10, max_features=sqrt, min_samples_split=2, n_estimators=50;, score=0.860 total time=   0.4s
# [CV 1/5; 14/48] START max_depth=10, max_features=sqrt, min_samples_split=2, n_estimators=100
# [CV 1/5; 14/48] END max_depth=10, max_features=sqrt, min_samples_split=2, n_estimators=100;, score=0.863 total time=   0.8s
# [CV 2/5; 14/48] START max_depth=10, max_features=sqrt, min_samples_split=2, n_estimators=100
# [CV 2/5; 14/48] END max_depth=10, max_features=sqrt, min_samples_split=2, n_estimators=100;, score=0.860 total time=   0.9s
# [CV 3/5; 14/48] START max_depth=10, max_features=sqrt, min_samples_split=2, n_estimators=100
# [CV 3/5; 14/48] END max_depth=10, max_features=sqrt, min_samples_split=2, n_estimators=100;, score=0.859 total time=   0.9s
# [CV 4/5; 14/48] START max_depth=10, max_features=sqrt, min_samples_split=2, n_estimators=100
# [CV 4/5; 14/48] END max_depth=10, max_features=sqrt, min_samples_split=2, n_estimators=100;, score=0.855 total time=   0.9s
# [CV 5/5; 14/48] START max_depth=10, max_features=sqrt, min_samples_split=2, n_estimators=100
# [CV 5/5; 14/48] END max_depth=10, max_features=sqrt, min_samples_split=2, n_estimators=100;, score=0.858 total time=   0.8s
# [CV 1/5; 15/48] START max_depth=10, max_features=sqrt, min_samples_split=2, n_estimators=250
# [CV 1/5; 15/48] END max_depth=10, max_features=sqrt, min_samples_split=2, n_estimators=250;, score=0.862 total time=   2.1s
# [CV 2/5; 15/48] START max_depth=10, max_features=sqrt, min_samples_split=2, n_estimators=250
# [CV 2/5; 15/48] END max_depth=10, max_features=sqrt, min_samples_split=2, n_estimators=250;, score=0.860 total time=   2.1s
# [CV 3/5; 15/48] START max_depth=10, max_features=sqrt, min_samples_split=2, n_estimators=250
# [CV 3/5; 15/48] END max_depth=10, max_features=sqrt, min_samples_split=2, n_estimators=250;, score=0.860 total time=   2.1s
# [CV 4/5; 15/48] START max_depth=10, max_features=sqrt, min_samples_split=2, n_estimators=250
# [CV 4/5; 15/48] END max_depth=10, max_features=sqrt, min_samples_split=2, n_estimators=250;, score=0.855 total time=   2.1s
# [CV 5/5; 15/48] START max_depth=10, max_features=sqrt, min_samples_split=2, n_estimators=250
# [CV 5/5; 15/48] END max_depth=10, max_features=sqrt, min_samples_split=2, n_estimators=250;, score=0.859 total time=   2.0s
# [CV 1/5; 16/48] START max_depth=10, max_features=sqrt, min_samples_split=4, n_estimators=50
# [CV 1/5; 16/48] END max_depth=10, max_features=sqrt, min_samples_split=4, n_estimators=50;, score=0.862 total time=   0.4s
# [CV 2/5; 16/48] START max_depth=10, max_features=sqrt, min_samples_split=4, n_estimators=50
# [CV 2/5; 16/48] END max_depth=10, max_features=sqrt, min_samples_split=4, n_estimators=50;, score=0.860 total time=   0.4s
# [CV 3/5; 16/48] START max_depth=10, max_features=sqrt, min_samples_split=4, n_estimators=50
# [CV 3/5; 16/48] END max_depth=10, max_features=sqrt, min_samples_split=4, n_estimators=50;, score=0.859 total time=   0.4s
# [CV 4/5; 16/48] START max_depth=10, max_features=sqrt, min_samples_split=4, n_estimators=50
# [CV 4/5; 16/48] END max_depth=10, max_features=sqrt, min_samples_split=4, n_estimators=50;, score=0.854 total time=   0.4s
# [CV 5/5; 16/48] START max_depth=10, max_features=sqrt, min_samples_split=4, n_estimators=50
# [CV 5/5; 16/48] END max_depth=10, max_features=sqrt, min_samples_split=4, n_estimators=50;, score=0.857 total time=   0.4s
# [CV 1/5; 17/48] START max_depth=10, max_features=sqrt, min_samples_split=4, n_estimators=100
# [CV 1/5; 17/48] END max_depth=10, max_features=sqrt, min_samples_split=4, n_estimators=100;, score=0.862 total time=   0.8s
# [CV 2/5; 17/48] START max_depth=10, max_features=sqrt, min_samples_split=4, n_estimators=100
# [CV 2/5; 17/48] END max_depth=10, max_features=sqrt, min_samples_split=4, n_estimators=100;, score=0.861 total time=   0.8s
# [CV 3/5; 17/48] START max_depth=10, max_features=sqrt, min_samples_split=4, n_estimators=100
# [CV 3/5; 17/48] END max_depth=10, max_features=sqrt, min_samples_split=4, n_estimators=100;, score=0.858 total time=   0.9s
# [CV 4/5; 17/48] START max_depth=10, max_features=sqrt, min_samples_split=4, n_estimators=100
# [CV 4/5; 17/48] END max_depth=10, max_features=sqrt, min_samples_split=4, n_estimators=100;, score=0.854 total time=   0.8s
# [CV 5/5; 17/48] START max_depth=10, max_features=sqrt, min_samples_split=4, n_estimators=100
# [CV 5/5; 17/48] END max_depth=10, max_features=sqrt, min_samples_split=4, n_estimators=100;, score=0.858 total time=   0.9s
# [CV 1/5; 18/48] START max_depth=10, max_features=sqrt, min_samples_split=4, n_estimators=250
# [CV 1/5; 18/48] END max_depth=10, max_features=sqrt, min_samples_split=4, n_estimators=250;, score=0.863 total time=   2.1s
# [CV 2/5; 18/48] START max_depth=10, max_features=sqrt, min_samples_split=4, n_estimators=250
# [CV 2/5; 18/48] END max_depth=10, max_features=sqrt, min_samples_split=4, n_estimators=250;, score=0.860 total time=   2.1s
# [CV 3/5; 18/48] START max_depth=10, max_features=sqrt, min_samples_split=4, n_estimators=250
# [CV 3/5; 18/48] END max_depth=10, max_features=sqrt, min_samples_split=4, n_estimators=250;, score=0.860 total time=   2.4s
# [CV 4/5; 18/48] START max_depth=10, max_features=sqrt, min_samples_split=4, n_estimators=250
# [CV 4/5; 18/48] END max_depth=10, max_features=sqrt, min_samples_split=4, n_estimators=250;, score=0.855 total time=   2.2s
# [CV 5/5; 18/48] START max_depth=10, max_features=sqrt, min_samples_split=4, n_estimators=250
# [CV 5/5; 18/48] END max_depth=10, max_features=sqrt, min_samples_split=4, n_estimators=250;, score=0.859 total time=   2.2s
# [CV 1/5; 19/48] START max_depth=10, max_features=log2, min_samples_split=2, n_estimators=50
# [CV 1/5; 19/48] END max_depth=10, max_features=log2, min_samples_split=2, n_estimators=50;, score=0.857 total time=   0.4s
# [CV 2/5; 19/48] START max_depth=10, max_features=log2, min_samples_split=2, n_estimators=50
# [CV 2/5; 19/48] END max_depth=10, max_features=log2, min_samples_split=2, n_estimators=50;, score=0.856 total time=   0.4s
# [CV 3/5; 19/48] START max_depth=10, max_features=log2, min_samples_split=2, n_estimators=50
# [CV 3/5; 19/48] END max_depth=10, max_features=log2, min_samples_split=2, n_estimators=50;, score=0.855 total time=   0.4s
# [CV 4/5; 19/48] START max_depth=10, max_features=log2, min_samples_split=2, n_estimators=50
# [CV 4/5; 19/48] END max_depth=10, max_features=log2, min_samples_split=2, n_estimators=50;, score=0.847 total time=   0.4s
# [CV 5/5; 19/48] START max_depth=10, max_features=log2, min_samples_split=2, n_estimators=50
# [CV 5/5; 19/48] END max_depth=10, max_features=log2, min_samples_split=2, n_estimators=50;, score=0.851 total time=   0.4s
# [CV 1/5; 20/48] START max_depth=10, max_features=log2, min_samples_split=2, n_estimators=100
# [CV 1/5; 20/48] END max_depth=10, max_features=log2, min_samples_split=2, n_estimators=100;, score=0.859 total time=   0.7s
# [CV 2/5; 20/48] START max_depth=10, max_features=log2, min_samples_split=2, n_estimators=100
# [CV 2/5; 20/48] END max_depth=10, max_features=log2, min_samples_split=2, n_estimators=100;, score=0.855 total time=   0.9s
# [CV 3/5; 20/48] START max_depth=10, max_features=log2, min_samples_split=2, n_estimators=100
# [CV 3/5; 20/48] END max_depth=10, max_features=log2, min_samples_split=2, n_estimators=100;, score=0.854 total time=   0.8s
# [CV 4/5; 20/48] START max_depth=10, max_features=log2, min_samples_split=2, n_estimators=100
# [CV 4/5; 20/48] END max_depth=10, max_features=log2, min_samples_split=2, n_estimators=100;, score=0.847 total time=   0.7s
# [CV 5/5; 20/48] START max_depth=10, max_features=log2, min_samples_split=2, n_estimators=100
# [CV 5/5; 20/48] END max_depth=10, max_features=log2, min_samples_split=2, n_estimators=100;, score=0.854 total time=   0.8s
# [CV 1/5; 21/48] START max_depth=10, max_features=log2, min_samples_split=2, n_estimators=250
# [CV 1/5; 21/48] END max_depth=10, max_features=log2, min_samples_split=2, n_estimators=250;, score=0.860 total time=   1.8s
# [CV 2/5; 21/48] START max_depth=10, max_features=log2, min_samples_split=2, n_estimators=250
# [CV 2/5; 21/48] END max_depth=10, max_features=log2, min_samples_split=2, n_estimators=250;, score=0.855 total time=   1.7s
# [CV 3/5; 21/48] START max_depth=10, max_features=log2, min_samples_split=2, n_estimators=250
# [CV 3/5; 21/48] END max_depth=10, max_features=log2, min_samples_split=2, n_estimators=250;, score=0.852 total time=   1.7s
# [CV 4/5; 21/48] START max_depth=10, max_features=log2, min_samples_split=2, n_estimators=250
# [CV 4/5; 21/48] END max_depth=10, max_features=log2, min_samples_split=2, n_estimators=250;, score=0.851 total time=   1.7s
# [CV 5/5; 21/48] START max_depth=10, max_features=log2, min_samples_split=2, n_estimators=250
# [CV 5/5; 21/48] END max_depth=10, max_features=log2, min_samples_split=2, n_estimators=250;, score=0.853 total time=   1.7s
# [CV 1/5; 22/48] START max_depth=10, max_features=log2, min_samples_split=4, n_estimators=50
# [CV 1/5; 22/48] END max_depth=10, max_features=log2, min_samples_split=4, n_estimators=50;, score=0.859 total time=   0.4s
# [CV 2/5; 22/48] START max_depth=10, max_features=log2, min_samples_split=4, n_estimators=50
# [CV 2/5; 22/48] END max_depth=10, max_features=log2, min_samples_split=4, n_estimators=50;, score=0.853 total time=   0.4s
# [CV 3/5; 22/48] START max_depth=10, max_features=log2, min_samples_split=4, n_estimators=50
# [CV 3/5; 22/48] END max_depth=10, max_features=log2, min_samples_split=4, n_estimators=50;, score=0.854 total time=   0.3s
# [CV 4/5; 22/48] START max_depth=10, max_features=log2, min_samples_split=4, n_estimators=50
# [CV 4/5; 22/48] END max_depth=10, max_features=log2, min_samples_split=4, n_estimators=50;, score=0.847 total time=   0.4s
# [CV 5/5; 22/48] START max_depth=10, max_features=log2, min_samples_split=4, n_estimators=50
# [CV 5/5; 22/48] END max_depth=10, max_features=log2, min_samples_split=4, n_estimators=50;, score=0.854 total time=   0.3s
# [CV 1/5; 23/48] START max_depth=10, max_features=log2, min_samples_split=4, n_estimators=100
# [CV 1/5; 23/48] END max_depth=10, max_features=log2, min_samples_split=4, n_estimators=100;, score=0.859 total time=   0.7s
# [CV 2/5; 23/48] START max_depth=10, max_features=log2, min_samples_split=4, n_estimators=100
# [CV 2/5; 23/48] END max_depth=10, max_features=log2, min_samples_split=4, n_estimators=100;, score=0.856 total time=   0.7s
# [CV 3/5; 23/48] START max_depth=10, max_features=log2, min_samples_split=4, n_estimators=100
# [CV 3/5; 23/48] END max_depth=10, max_features=log2, min_samples_split=4, n_estimators=100;, score=0.852 total time=   0.7s
# [CV 4/5; 23/48] START max_depth=10, max_features=log2, min_samples_split=4, n_estimators=100
# [CV 4/5; 23/48] END max_depth=10, max_features=log2, min_samples_split=4, n_estimators=100;, score=0.850 total time=   0.7s
# [CV 5/5; 23/48] START max_depth=10, max_features=log2, min_samples_split=4, n_estimators=100
# [CV 5/5; 23/48] END max_depth=10, max_features=log2, min_samples_split=4, n_estimators=100;, score=0.854 total time=   0.7s
# [CV 1/5; 24/48] START max_depth=10, max_features=log2, min_samples_split=4, n_estimators=250
# [CV 1/5; 24/48] END max_depth=10, max_features=log2, min_samples_split=4, n_estimators=250;, score=0.858 total time=   1.7s
# [CV 2/5; 24/48] START max_depth=10, max_features=log2, min_samples_split=4, n_estimators=250
# [CV 2/5; 24/48] END max_depth=10, max_features=log2, min_samples_split=4, n_estimators=250;, score=0.855 total time=   1.7s
# [CV 3/5; 24/48] START max_depth=10, max_features=log2, min_samples_split=4, n_estimators=250
# [CV 3/5; 24/48] END max_depth=10, max_features=log2, min_samples_split=4, n_estimators=250;, score=0.854 total time=   1.8s
# [CV 4/5; 24/48] START max_depth=10, max_features=log2, min_samples_split=4, n_estimators=250
# [CV 4/5; 24/48] END max_depth=10, max_features=log2, min_samples_split=4, n_estimators=250;, score=0.848 total time=   1.7s
# [CV 5/5; 24/48] START max_depth=10, max_features=log2, min_samples_split=4, n_estimators=250
# [CV 5/5; 24/48] END max_depth=10, max_features=log2, min_samples_split=4, n_estimators=250;, score=0.853 total time=   1.8s
# [CV 1/5; 25/48] START max_depth=20, max_features=sqrt, min_samples_split=2, n_estimators=50
# [CV 1/5; 25/48] END max_depth=20, max_features=sqrt, min_samples_split=2, n_estimators=50;, score=0.864 total time=   0.7s
# [CV 2/5; 25/48] START max_depth=20, max_features=sqrt, min_samples_split=2, n_estimators=50
# [CV 2/5; 25/48] END max_depth=20, max_features=sqrt, min_samples_split=2, n_estimators=50;, score=0.864 total time=   0.7s
# [CV 3/5; 25/48] START max_depth=20, max_features=sqrt, min_samples_split=2, n_estimators=50
# [CV 3/5; 25/48] END max_depth=20, max_features=sqrt, min_samples_split=2, n_estimators=50;, score=0.864 total time=   0.7s
# [CV 4/5; 25/48] START max_depth=20, max_features=sqrt, min_samples_split=2, n_estimators=50
# [CV 4/5; 25/48] END max_depth=20, max_features=sqrt, min_samples_split=2, n_estimators=50;, score=0.859 total time=   0.7s
# [CV 5/5; 25/48] START max_depth=20, max_features=sqrt, min_samples_split=2, n_estimators=50
# [CV 5/5; 25/48] END max_depth=20, max_features=sqrt, min_samples_split=2, n_estimators=50;, score=0.867 total time=   0.7s
# [CV 1/5; 26/48] START max_depth=20, max_features=sqrt, min_samples_split=2, n_estimators=100
# [CV 1/5; 26/48] END max_depth=20, max_features=sqrt, min_samples_split=2, n_estimators=100;, score=0.865 total time=   1.3s
# [CV 2/5; 26/48] START max_depth=20, max_features=sqrt, min_samples_split=2, n_estimators=100
# [CV 2/5; 26/48] END max_depth=20, max_features=sqrt, min_samples_split=2, n_estimators=100;, score=0.864 total time=   1.4s
# [CV 3/5; 26/48] START max_depth=20, max_features=sqrt, min_samples_split=2, n_estimators=100
# [CV 3/5; 26/48] END max_depth=20, max_features=sqrt, min_samples_split=2, n_estimators=100;, score=0.865 total time=   1.4s
# [CV 4/5; 26/48] START max_depth=20, max_features=sqrt, min_samples_split=2, n_estimators=100
# [CV 4/5; 26/48] END max_depth=20, max_features=sqrt, min_samples_split=2, n_estimators=100;, score=0.861 total time=   1.4s
# [CV 5/5; 26/48] START max_depth=20, max_features=sqrt, min_samples_split=2, n_estimators=100
# [CV 5/5; 26/48] END max_depth=20, max_features=sqrt, min_samples_split=2, n_estimators=100;, score=0.869 total time=   1.4s
# [CV 1/5; 27/48] START max_depth=20, max_features=sqrt, min_samples_split=2, n_estimators=250
# [CV 1/5; 27/48] END max_depth=20, max_features=sqrt, min_samples_split=2, n_estimators=250;, score=0.865 total time=   3.4s
# [CV 2/5; 27/48] START max_depth=20, max_features=sqrt, min_samples_split=2, n_estimators=250
# [CV 2/5; 27/48] END max_depth=20, max_features=sqrt, min_samples_split=2, n_estimators=250;, score=0.865 total time=   3.5s
# [CV 3/5; 27/48] START max_depth=20, max_features=sqrt, min_samples_split=2, n_estimators=250
# [CV 3/5; 27/48] END max_depth=20, max_features=sqrt, min_samples_split=2, n_estimators=250;, score=0.863 total time=   3.8s
# [CV 4/5; 27/48] START max_depth=20, max_features=sqrt, min_samples_split=2, n_estimators=250
# [CV 4/5; 27/48] END max_depth=20, max_features=sqrt, min_samples_split=2, n_estimators=250;, score=0.861 total time=   3.4s
# [CV 5/5; 27/48] START max_depth=20, max_features=sqrt, min_samples_split=2, n_estimators=250
# [CV 5/5; 27/48] END max_depth=20, max_features=sqrt, min_samples_split=2, n_estimators=250;, score=0.866 total time=   3.4s
# [CV 1/5; 28/48] START max_depth=20, max_features=sqrt, min_samples_split=4, n_estimators=50
# [CV 1/5; 28/48] END max_depth=20, max_features=sqrt, min_samples_split=4, n_estimators=50;, score=0.867 total time=   0.7s
# [CV 2/5; 28/48] START max_depth=20, max_features=sqrt, min_samples_split=4, n_estimators=50
# [CV 2/5; 28/48] END max_depth=20, max_features=sqrt, min_samples_split=4, n_estimators=50;, score=0.865 total time=   0.7s
# [CV 3/5; 28/48] START max_depth=20, max_features=sqrt, min_samples_split=4, n_estimators=50
# [CV 3/5; 28/48] END max_depth=20, max_features=sqrt, min_samples_split=4, n_estimators=50;, score=0.865 total time=   0.7s
# [CV 4/5; 28/48] START max_depth=20, max_features=sqrt, min_samples_split=4, n_estimators=50
# [CV 4/5; 28/48] END max_depth=20, max_features=sqrt, min_samples_split=4, n_estimators=50;, score=0.863 total time=   0.7s
# [CV 5/5; 28/48] START max_depth=20, max_features=sqrt, min_samples_split=4, n_estimators=50
# [CV 5/5; 28/48] END max_depth=20, max_features=sqrt, min_samples_split=4, n_estimators=50;, score=0.868 total time=   0.7s
# [CV 1/5; 29/48] START max_depth=20, max_features=sqrt, min_samples_split=4, n_estimators=100
# [CV 1/5; 29/48] END max_depth=20, max_features=sqrt, min_samples_split=4, n_estimators=100;, score=0.865 total time=   1.4s
# [CV 2/5; 29/48] START max_depth=20, max_features=sqrt, min_samples_split=4, n_estimators=100
# [CV 2/5; 29/48] END max_depth=20, max_features=sqrt, min_samples_split=4, n_estimators=100;, score=0.865 total time=   1.3s
# [CV 3/5; 29/48] START max_depth=20, max_features=sqrt, min_samples_split=4, n_estimators=100
# [CV 3/5; 29/48] END max_depth=20, max_features=sqrt, min_samples_split=4, n_estimators=100;, score=0.863 total time=   1.4s
# [CV 4/5; 29/48] START max_depth=20, max_features=sqrt, min_samples_split=4, n_estimators=100
# [CV 4/5; 29/48] END max_depth=20, max_features=sqrt, min_samples_split=4, n_estimators=100;, score=0.861 total time=   1.3s
# [CV 5/5; 29/48] START max_depth=20, max_features=sqrt, min_samples_split=4, n_estimators=100
# [CV 5/5; 29/48] END max_depth=20, max_features=sqrt, min_samples_split=4, n_estimators=100;, score=0.868 total time=   1.4s
# [CV 1/5; 30/48] START max_depth=20, max_features=sqrt, min_samples_split=4, n_estimators=250
# [CV 1/5; 30/48] END max_depth=20, max_features=sqrt, min_samples_split=4, n_estimators=250;, score=0.866 total time=   3.6s
# [CV 2/5; 30/48] START max_depth=20, max_features=sqrt, min_samples_split=4, n_estimators=250
# [CV 2/5; 30/48] END max_depth=20, max_features=sqrt, min_samples_split=4, n_estimators=250;, score=0.865 total time=   3.9s
# [CV 3/5; 30/48] START max_depth=20, max_features=sqrt, min_samples_split=4, n_estimators=250
# [CV 3/5; 30/48] END max_depth=20, max_features=sqrt, min_samples_split=4, n_estimators=250;, score=0.864 total time=   4.1s
# [CV 4/5; 30/48] START max_depth=20, max_features=sqrt, min_samples_split=4, n_estimators=250
# [CV 4/5; 30/48] END max_depth=20, max_features=sqrt, min_samples_split=4, n_estimators=250;, score=0.861 total time=   3.6s
# [CV 5/5; 30/48] START max_depth=20, max_features=sqrt, min_samples_split=4, n_estimators=250
# [CV 5/5; 30/48] END max_depth=20, max_features=sqrt, min_samples_split=4, n_estimators=250;, score=0.869 total time=   3.7s
# [CV 1/5; 31/48] START max_depth=20, max_features=log2, min_samples_split=2, n_estimators=50
# [CV 1/5; 31/48] END max_depth=20, max_features=log2, min_samples_split=2, n_estimators=50;, score=0.865 total time=   0.6s
# [CV 2/5; 31/48] START max_depth=20, max_features=log2, min_samples_split=2, n_estimators=50
# [CV 2/5; 31/48] END max_depth=20, max_features=log2, min_samples_split=2, n_estimators=50;, score=0.860 total time=   0.6s
# [CV 3/5; 31/48] START max_depth=20, max_features=log2, min_samples_split=2, n_estimators=50
# [CV 3/5; 31/48] END max_depth=20, max_features=log2, min_samples_split=2, n_estimators=50;, score=0.860 total time=   0.6s
# [CV 4/5; 31/48] START max_depth=20, max_features=log2, min_samples_split=2, n_estimators=50
# [CV 4/5; 31/48] END max_depth=20, max_features=log2, min_samples_split=2, n_estimators=50;, score=0.858 total time=   0.6s
# [CV 5/5; 31/48] START max_depth=20, max_features=log2, min_samples_split=2, n_estimators=50
# [CV 5/5; 31/48] END max_depth=20, max_features=log2, min_samples_split=2, n_estimators=50;, score=0.865 total time=   0.6s
# [CV 1/5; 32/48] START max_depth=20, max_features=log2, min_samples_split=2, n_estimators=100
# [CV 1/5; 32/48] END max_depth=20, max_features=log2, min_samples_split=2, n_estimators=100;, score=0.864 total time=   1.2s
# [CV 2/5; 32/48] START max_depth=20, max_features=log2, min_samples_split=2, n_estimators=100
# [CV 2/5; 32/48] END max_depth=20, max_features=log2, min_samples_split=2, n_estimators=100;, score=0.863 total time=   1.2s
# [CV 3/5; 32/48] START max_depth=20, max_features=log2, min_samples_split=2, n_estimators=100
# [CV 3/5; 32/48] END max_depth=20, max_features=log2, min_samples_split=2, n_estimators=100;, score=0.862 total time=   1.1s
# [CV 4/5; 32/48] START max_depth=20, max_features=log2, min_samples_split=2, n_estimators=100
# [CV 4/5; 32/48] END max_depth=20, max_features=log2, min_samples_split=2, n_estimators=100;, score=0.860 total time=   1.2s
# [CV 5/5; 32/48] START max_depth=20, max_features=log2, min_samples_split=2, n_estimators=100
# [CV 5/5; 32/48] END max_depth=20, max_features=log2, min_samples_split=2, n_estimators=100;, score=0.866 total time=   1.2s
# [CV 1/5; 33/48] START max_depth=20, max_features=log2, min_samples_split=2, n_estimators=250
# [CV 1/5; 33/48] END max_depth=20, max_features=log2, min_samples_split=2, n_estimators=250;, score=0.863 total time=   2.9s
# [CV 2/5; 33/48] START max_depth=20, max_features=log2, min_samples_split=2, n_estimators=250
# [CV 2/5; 33/48] END max_depth=20, max_features=log2, min_samples_split=2, n_estimators=250;, score=0.863 total time=   2.9s
# [CV 3/5; 33/48] START max_depth=20, max_features=log2, min_samples_split=2, n_estimators=250
# [CV 3/5; 33/48] END max_depth=20, max_features=log2, min_samples_split=2, n_estimators=250;, score=0.863 total time=   2.9s
# [CV 4/5; 33/48] START max_depth=20, max_features=log2, min_samples_split=2, n_estimators=250
# [CV 4/5; 33/48] END max_depth=20, max_features=log2, min_samples_split=2, n_estimators=250;, score=0.860 total time=   2.9s
# [CV 5/5; 33/48] START max_depth=20, max_features=log2, min_samples_split=2, n_estimators=250
# [CV 5/5; 33/48] END max_depth=20, max_features=log2, min_samples_split=2, n_estimators=250;, score=0.868 total time=   2.9s
# [CV 1/5; 34/48] START max_depth=20, max_features=log2, min_samples_split=4, n_estimators=50
# [CV 1/5; 34/48] END max_depth=20, max_features=log2, min_samples_split=4, n_estimators=50;, score=0.863 total time=   0.6s
# [CV 2/5; 34/48] START max_depth=20, max_features=log2, min_samples_split=4, n_estimators=50
# [CV 2/5; 34/48] END max_depth=20, max_features=log2, min_samples_split=4, n_estimators=50;, score=0.863 total time=   0.6s
# [CV 3/5; 34/48] START max_depth=20, max_features=log2, min_samples_split=4, n_estimators=50
# [CV 3/5; 34/48] END max_depth=20, max_features=log2, min_samples_split=4, n_estimators=50;, score=0.862 total time=   0.6s
# [CV 4/5; 34/48] START max_depth=20, max_features=log2, min_samples_split=4, n_estimators=50
# [CV 4/5; 34/48] END max_depth=20, max_features=log2, min_samples_split=4, n_estimators=50;, score=0.860 total time=   0.6s
# [CV 5/5; 34/48] START max_depth=20, max_features=log2, min_samples_split=4, n_estimators=50
# [CV 5/5; 34/48] END max_depth=20, max_features=log2, min_samples_split=4, n_estimators=50;, score=0.864 total time=   0.6s
# [CV 1/5; 35/48] START max_depth=20, max_features=log2, min_samples_split=4, n_estimators=100
# [CV 1/5; 35/48] END max_depth=20, max_features=log2, min_samples_split=4, n_estimators=100;, score=0.864 total time=   1.1s
# [CV 2/5; 35/48] START max_depth=20, max_features=log2, min_samples_split=4, n_estimators=100
# [CV 2/5; 35/48] END max_depth=20, max_features=log2, min_samples_split=4, n_estimators=100;, score=0.863 total time=   1.2s
# [CV 3/5; 35/48] START max_depth=20, max_features=log2, min_samples_split=4, n_estimators=100
# [CV 3/5; 35/48] END max_depth=20, max_features=log2, min_samples_split=4, n_estimators=100;, score=0.861 total time=   1.2s
# [CV 4/5; 35/48] START max_depth=20, max_features=log2, min_samples_split=4, n_estimators=100
# [CV 4/5; 35/48] END max_depth=20, max_features=log2, min_samples_split=4, n_estimators=100;, score=0.861 total time=   1.2s
# [CV 5/5; 35/48] START max_depth=20, max_features=log2, min_samples_split=4, n_estimators=100
# [CV 5/5; 35/48] END max_depth=20, max_features=log2, min_samples_split=4, n_estimators=100;, score=0.867 total time=   1.1s
# [CV 1/5; 36/48] START max_depth=20, max_features=log2, min_samples_split=4, n_estimators=250
# [CV 1/5; 36/48] END max_depth=20, max_features=log2, min_samples_split=4, n_estimators=250;, score=0.864 total time=   3.0s
# [CV 2/5; 36/48] START max_depth=20, max_features=log2, min_samples_split=4, n_estimators=250
# [CV 2/5; 36/48] END max_depth=20, max_features=log2, min_samples_split=4, n_estimators=250;, score=0.864 total time=   3.0s
# [CV 3/5; 36/48] START max_depth=20, max_features=log2, min_samples_split=4, n_estimators=250
# [CV 3/5; 36/48] END max_depth=20, max_features=log2, min_samples_split=4, n_estimators=250;, score=0.862 total time=   3.0s
# [CV 4/5; 36/48] START max_depth=20, max_features=log2, min_samples_split=4, n_estimators=250
# [CV 4/5; 36/48] END max_depth=20, max_features=log2, min_samples_split=4, n_estimators=250;, score=0.861 total time=   2.9s
# [CV 5/5; 36/48] START max_depth=20, max_features=log2, min_samples_split=4, n_estimators=250
# [CV 5/5; 36/48] END max_depth=20, max_features=log2, min_samples_split=4, n_estimators=250;, score=0.866 total time=   2.9s
# [CV 1/5; 37/48] START max_depth=None, max_features=sqrt, min_samples_split=2, n_estimators=50
# [CV 1/5; 37/48] END max_depth=None, max_features=sqrt, min_samples_split=2, n_estimators=50;, score=0.849 total time=   1.0s
# [CV 2/5; 37/48] START max_depth=None, max_features=sqrt, min_samples_split=2, n_estimators=50
# [CV 2/5; 37/48] END max_depth=None, max_features=sqrt, min_samples_split=2, n_estimators=50;, score=0.850 total time=   0.9s
# [CV 3/5; 37/48] START max_depth=None, max_features=sqrt, min_samples_split=2, n_estimators=50
# [CV 3/5; 37/48] END max_depth=None, max_features=sqrt, min_samples_split=2, n_estimators=50;, score=0.847 total time=   0.9s
# [CV 4/5; 37/48] START max_depth=None, max_features=sqrt, min_samples_split=2, n_estimators=50
# [CV 4/5; 37/48] END max_depth=None, max_features=sqrt, min_samples_split=2, n_estimators=50;, score=0.846 total time=   0.9s
# [CV 5/5; 37/48] START max_depth=None, max_features=sqrt, min_samples_split=2, n_estimators=50
# [CV 5/5; 37/48] END max_depth=None, max_features=sqrt, min_samples_split=2, n_estimators=50;, score=0.850 total time=   1.0s
# [CV 1/5; 38/48] START max_depth=None, max_features=sqrt, min_samples_split=2, n_estimators=100
# [CV 1/5; 38/48] END max_depth=None, max_features=sqrt, min_samples_split=2, n_estimators=100;, score=0.847 total time=   1.9s
# [CV 2/5; 38/48] START max_depth=None, max_features=sqrt, min_samples_split=2, n_estimators=100
# [CV 2/5; 38/48] END max_depth=None, max_features=sqrt, min_samples_split=2, n_estimators=100;, score=0.849 total time=   1.8s
# [CV 3/5; 38/48] START max_depth=None, max_features=sqrt, min_samples_split=2, n_estimators=100
# [CV 3/5; 38/48] END max_depth=None, max_features=sqrt, min_samples_split=2, n_estimators=100;, score=0.849 total time=   1.8s
# [CV 4/5; 38/48] START max_depth=None, max_features=sqrt, min_samples_split=2, n_estimators=100
# [CV 4/5; 38/48] END max_depth=None, max_features=sqrt, min_samples_split=2, n_estimators=100;, score=0.849 total time=   1.8s
# [CV 5/5; 38/48] START max_depth=None, max_features=sqrt, min_samples_split=2, n_estimators=100
# [CV 5/5; 38/48] END max_depth=None, max_features=sqrt, min_samples_split=2, n_estimators=100;, score=0.851 total time=   1.9s
# [CV 1/5; 39/48] START max_depth=None, max_features=sqrt, min_samples_split=2, n_estimators=250
# [CV 1/5; 39/48] END max_depth=None, max_features=sqrt, min_samples_split=2, n_estimators=250;, score=0.849 total time=   4.6s
# [CV 2/5; 39/48] START max_depth=None, max_features=sqrt, min_samples_split=2, n_estimators=250
# [CV 2/5; 39/48] END max_depth=None, max_features=sqrt, min_samples_split=2, n_estimators=250;, score=0.850 total time=   4.6s
# [CV 3/5; 39/48] START max_depth=None, max_features=sqrt, min_samples_split=2, n_estimators=250
# [CV 3/5; 39/48] END max_depth=None, max_features=sqrt, min_samples_split=2, n_estimators=250;, score=0.848 total time=   4.6s
# [CV 4/5; 39/48] START max_depth=None, max_features=sqrt, min_samples_split=2, n_estimators=250
# [CV 4/5; 39/48] END max_depth=None, max_features=sqrt, min_samples_split=2, n_estimators=250;, score=0.849 total time=   4.7s
# [CV 5/5; 39/48] START max_depth=None, max_features=sqrt, min_samples_split=2, n_estimators=250
# [CV 5/5; 39/48] END max_depth=None, max_features=sqrt, min_samples_split=2, n_estimators=250;, score=0.852 total time=   4.7s
# [CV 1/5; 40/48] START max_depth=None, max_features=sqrt, min_samples_split=4, n_estimators=50
# [CV 1/5; 40/48] END max_depth=None, max_features=sqrt, min_samples_split=4, n_estimators=50;, score=0.852 total time=   0.9s
# [CV 2/5; 40/48] START max_depth=None, max_features=sqrt, min_samples_split=4, n_estimators=50
# [CV 2/5; 40/48] END max_depth=None, max_features=sqrt, min_samples_split=4, n_estimators=50;, score=0.851 total time=   0.9s
# [CV 3/5; 40/48] START max_depth=None, max_features=sqrt, min_samples_split=4, n_estimators=50
# [CV 3/5; 40/48] END max_depth=None, max_features=sqrt, min_samples_split=4, n_estimators=50;, score=0.854 total time=   0.9s
# [CV 4/5; 40/48] START max_depth=None, max_features=sqrt, min_samples_split=4, n_estimators=50
# [CV 4/5; 40/48] END max_depth=None, max_features=sqrt, min_samples_split=4, n_estimators=50;, score=0.853 total time=   0.9s
# [CV 5/5; 40/48] START max_depth=None, max_features=sqrt, min_samples_split=4, n_estimators=50
# [CV 5/5; 40/48] END max_depth=None, max_features=sqrt, min_samples_split=4, n_estimators=50;, score=0.857 total time=   0.9s
# [CV 1/5; 41/48] START max_depth=None, max_features=sqrt, min_samples_split=4, n_estimators=100
# [CV 1/5; 41/48] END max_depth=None, max_features=sqrt, min_samples_split=4, n_estimators=100;, score=0.853 total time=   1.8s
# [CV 2/5; 41/48] START max_depth=None, max_features=sqrt, min_samples_split=4, n_estimators=100
# [CV 2/5; 41/48] END max_depth=None, max_features=sqrt, min_samples_split=4, n_estimators=100;, score=0.853 total time=   1.8s
# [CV 3/5; 41/48] START max_depth=None, max_features=sqrt, min_samples_split=4, n_estimators=100
# [CV 3/5; 41/48] END max_depth=None, max_features=sqrt, min_samples_split=4, n_estimators=100;, score=0.855 total time=   1.8s
# [CV 4/5; 41/48] START max_depth=None, max_features=sqrt, min_samples_split=4, n_estimators=100
# [CV 4/5; 41/48] END max_depth=None, max_features=sqrt, min_samples_split=4, n_estimators=100;, score=0.852 total time=   1.8s
# [CV 5/5; 41/48] START max_depth=None, max_features=sqrt, min_samples_split=4, n_estimators=100
# [CV 5/5; 41/48] END max_depth=None, max_features=sqrt, min_samples_split=4, n_estimators=100;, score=0.855 total time=   1.7s
# [CV 1/5; 42/48] START max_depth=None, max_features=sqrt, min_samples_split=4, n_estimators=250
# [CV 1/5; 42/48] END max_depth=None, max_features=sqrt, min_samples_split=4, n_estimators=250;, score=0.855 total time=   4.4s
# [CV 2/5; 42/48] START max_depth=None, max_features=sqrt, min_samples_split=4, n_estimators=250
# [CV 2/5; 42/48] END max_depth=None, max_features=sqrt, min_samples_split=4, n_estimators=250;, score=0.853 total time=   4.5s
# [CV 3/5; 42/48] START max_depth=None, max_features=sqrt, min_samples_split=4, n_estimators=250
# [CV 3/5; 42/48] END max_depth=None, max_features=sqrt, min_samples_split=4, n_estimators=250;, score=0.855 total time=   4.4s
# [CV 4/5; 42/48] START max_depth=None, max_features=sqrt, min_samples_split=4, n_estimators=250
# [CV 4/5; 42/48] END max_depth=None, max_features=sqrt, min_samples_split=4, n_estimators=250;, score=0.854 total time=   4.6s
# [CV 5/5; 42/48] START max_depth=None, max_features=sqrt, min_samples_split=4, n_estimators=250
# [CV 5/5; 42/48] END max_depth=None, max_features=sqrt, min_samples_split=4, n_estimators=250;, score=0.856 total time=   4.5s
# [CV 1/5; 43/48] START max_depth=None, max_features=log2, min_samples_split=2, n_estimators=50
# [CV 1/5; 43/48] END max_depth=None, max_features=log2, min_samples_split=2, n_estimators=50;, score=0.846 total time=   0.9s
# [CV 2/5; 43/48] START max_depth=None, max_features=log2, min_samples_split=2, n_estimators=50
# [CV 2/5; 43/48] END max_depth=None, max_features=log2, min_samples_split=2, n_estimators=50;, score=0.847 total time=   0.9s
# [CV 3/5; 43/48] START max_depth=None, max_features=log2, min_samples_split=2, n_estimators=50
# [CV 3/5; 43/48] END max_depth=None, max_features=log2, min_samples_split=2, n_estimators=50;, score=0.846 total time=   0.9s
# [CV 4/5; 43/48] START max_depth=None, max_features=log2, min_samples_split=2, n_estimators=50
# [CV 4/5; 43/48] END max_depth=None, max_features=log2, min_samples_split=2, n_estimators=50;, score=0.846 total time=   0.9s
# [CV 5/5; 43/48] START max_depth=None, max_features=log2, min_samples_split=2, n_estimators=50
# [CV 5/5; 43/48] END max_depth=None, max_features=log2, min_samples_split=2, n_estimators=50;, score=0.848 total time=   0.9s
# [CV 1/5; 44/48] START max_depth=None, max_features=log2, min_samples_split=2, n_estimators=100
# [CV 1/5; 44/48] END max_depth=None, max_features=log2, min_samples_split=2, n_estimators=100;, score=0.844 total time=   1.7s
# [CV 2/5; 44/48] START max_depth=None, max_features=log2, min_samples_split=2, n_estimators=100
# [CV 2/5; 44/48] END max_depth=None, max_features=log2, min_samples_split=2, n_estimators=100;, score=0.849 total time=   1.7s
# [CV 3/5; 44/48] START max_depth=None, max_features=log2, min_samples_split=2, n_estimators=100
# [CV 3/5; 44/48] END max_depth=None, max_features=log2, min_samples_split=2, n_estimators=100;, score=0.845 total time=   1.7s
# [CV 4/5; 44/48] START max_depth=None, max_features=log2, min_samples_split=2, n_estimators=100
# [CV 4/5; 44/48] END max_depth=None, max_features=log2, min_samples_split=2, n_estimators=100;, score=0.848 total time=   1.7s
# [CV 5/5; 44/48] START max_depth=None, max_features=log2, min_samples_split=2, n_estimators=100
# [CV 5/5; 44/48] END max_depth=None, max_features=log2, min_samples_split=2, n_estimators=100;, score=0.848 total time=   1.7s
# [CV 1/5; 45/48] START max_depth=None, max_features=log2, min_samples_split=2, n_estimators=250
# [CV 1/5; 45/48] END max_depth=None, max_features=log2, min_samples_split=2, n_estimators=250;, score=0.847 total time=   4.3s
# [CV 2/5; 45/48] START max_depth=None, max_features=log2, min_samples_split=2, n_estimators=250
# [CV 2/5; 45/48] END max_depth=None, max_features=log2, min_samples_split=2, n_estimators=250;, score=0.850 total time=   4.2s
# [CV 3/5; 45/48] START max_depth=None, max_features=log2, min_samples_split=2, n_estimators=250
# [CV 3/5; 45/48] END max_depth=None, max_features=log2, min_samples_split=2, n_estimators=250;, score=0.848 total time=   4.2s
# [CV 4/5; 45/48] START max_depth=None, max_features=log2, min_samples_split=2, n_estimators=250
# [CV 4/5; 45/48] END max_depth=None, max_features=log2, min_samples_split=2, n_estimators=250;, score=0.849 total time=   4.3s
# [CV 5/5; 45/48] START max_depth=None, max_features=log2, min_samples_split=2, n_estimators=250
# [CV 5/5; 45/48] END max_depth=None, max_features=log2, min_samples_split=2, n_estimators=250;, score=0.848 total time=   4.7s
# [CV 1/5; 46/48] START max_depth=None, max_features=log2, min_samples_split=4, n_estimators=50
# [CV 1/5; 46/48] END max_depth=None, max_features=log2, min_samples_split=4, n_estimators=50;, score=0.853 total time=   0.9s
# [CV 2/5; 46/48] START max_depth=None, max_features=log2, min_samples_split=4, n_estimators=50
# [CV 2/5; 46/48] END max_depth=None, max_features=log2, min_samples_split=4, n_estimators=50;, score=0.851 total time=   0.8s
# [CV 3/5; 46/48] START max_depth=None, max_features=log2, min_samples_split=4, n_estimators=50
# [CV 3/5; 46/48] END max_depth=None, max_features=log2, min_samples_split=4, n_estimators=50;, score=0.853 total time=   0.8s
# [CV 4/5; 46/48] START max_depth=None, max_features=log2, min_samples_split=4, n_estimators=50
# [CV 4/5; 46/48] END max_depth=None, max_features=log2, min_samples_split=4, n_estimators=50;, score=0.849 total time=   0.8s
# [CV 5/5; 46/48] START max_depth=None, max_features=log2, min_samples_split=4, n_estimators=50
# [CV 5/5; 46/48] END max_depth=None, max_features=log2, min_samples_split=4, n_estimators=50;, score=0.855 total time=   0.8s
# [CV 1/5; 47/48] START max_depth=None, max_features=log2, min_samples_split=4, n_estimators=100
# [CV 1/5; 47/48] END max_depth=None, max_features=log2, min_samples_split=4, n_estimators=100;, score=0.851 total time=   1.7s
# [CV 2/5; 47/48] START max_depth=None, max_features=log2, min_samples_split=4, n_estimators=100
# [CV 2/5; 47/48] END max_depth=None, max_features=log2, min_samples_split=4, n_estimators=100;, score=0.854 total time=   1.6s
# [CV 3/5; 47/48] START max_depth=None, max_features=log2, min_samples_split=4, n_estimators=100
# [CV 3/5; 47/48] END max_depth=None, max_features=log2, min_samples_split=4, n_estimators=100;, score=0.850 total time=   1.8s
# [CV 4/5; 47/48] START max_depth=None, max_features=log2, min_samples_split=4, n_estimators=100
# [CV 4/5; 47/48] END max_depth=None, max_features=log2, min_samples_split=4, n_estimators=100;, score=0.852 total time=   1.8s
# [CV 5/5; 47/48] START max_depth=None, max_features=log2, min_samples_split=4, n_estimators=100
# [CV 5/5; 47/48] END max_depth=None, max_features=log2, min_samples_split=4, n_estimators=100;, score=0.856 total time=   1.7s
# [CV 1/5; 48/48] START max_depth=None, max_features=log2, min_samples_split=4, n_estimators=250
# [CV 1/5; 48/48] END max_depth=None, max_features=log2, min_samples_split=4, n_estimators=250;, score=0.851 total time=   4.2s
# [CV 2/5; 48/48] START max_depth=None, max_features=log2, min_samples_split=4, n_estimators=250
# [CV 2/5; 48/48] END max_depth=None, max_features=log2, min_samples_split=4, n_estimators=250;, score=0.854 total time=   4.2s
# [CV 3/5; 48/48] START max_depth=None, max_features=log2, min_samples_split=4, n_estimators=250
# [CV 3/5; 48/48] END max_depth=None, max_features=log2, min_samples_split=4, n_estimators=250;, score=0.851 total time=   4.2s
# [CV 4/5; 48/48] START max_depth=None, max_features=log2, min_samples_split=4, n_estimators=250
# [CV 4/5; 48/48] END max_depth=None, max_features=log2, min_samples_split=4, n_estimators=250;, score=0.853 total time=   4.2s
# [CV 5/5; 48/48] START max_depth=None, max_features=log2, min_samples_split=4, n_estimators=250
# [CV 5/5; 48/48] END max_depth=None, max_features=log2, min_samples_split=4, n_estimators=250;, score=0.856 total time=   4.1s
# GridSearchCV(estimator=RandomForestClassifier(),
#              param_grid={'max_depth': [5, 10, 20, None],
#                          'max_features': ['sqrt', 'log2'],
#                          'min_samples_split': [2, 4],
#                          'n_estimators': [50, 100, 250]},
#              verbose=10)

# %%
grid_search.best_estimator_
# Out:
# RandomForestClassifier(max_depth=20, min_samples_split=4, n_estimators=50)

# %%
final = grid_search.best_estimator_
final.score(test_x, test_y)
# Out:
# 0.8686661889650936

# %%
importances = dict(zip(final.feature_names_in_, final.feature_importances_))
importances = {k: v for k, v in sorted(importances.items(), key = lambda x: x[1], reverse=True)}

# %%
importances
# Out:
# {'capital-gain': np.float64(0.1416957743359742),
#  'educational-num': np.float64(0.14043062564430836),
#  'marital-status_Married-civ-spouse': np.float64(0.11550828290202313),
#  'age': np.float64(0.10443199012047767),
#  'relationship_Husband': np.float64(0.09062453373673864),
#  'hours-per-week': np.float64(0.06551974989967149),
#  'capital-loss': np.float64(0.046612060195873044),
#  'marital-status_Never-married': np.float64(0.03211354145254891),
#  'occupation_Exec-managerial': np.float64(0.02935237793023906),
#  'occupation_Prof-specialty': np.float64(0.025080354963647845),
#  'gender': np.float64(0.018050528353506255),
#  'relationship_Not-in-family': np.float64(0.016538205250654726),
#  'relationship_Own-child': np.float64(0.014423811878284822),
#  'relationship_Wife': np.float64(0.014222597414339806),
#  'relationship_Unmarried': np.float64(0.010375478030326872),
#  'occupation_Other-service': np.float64(0.010002280307063294),
#  'marital-status_Divorced': np.float64(0.00933733367728216),
#  'workclass_Self-emp-not-inc': np.float64(0.008065212782358396),
#  'workclass_Self-emp-inc': np.float64(0.006812888347215111),
#  'occupation_Farming-fishing': np.float64(0.006293235622860164),
#  'workclass_Private': np.float64(0.00591753619068449),
#  'native-country_United-States': np.float64(0.005102365836579513),
#  'race_White': np.float64(0.0048908670144197555),
#  'workclass_Federal-gov': np.float64(0.004658144445147043),
#  'occupation_Craft-repair': np.float64(0.004194551163153585),
#  'workclass_Local-gov': np.float64(0.004115089131650474),
#  'occupation_Sales': np.float64(0.004067747580942482),
#  'occupation_Machine-op-inspct': np.float64(0.004057020118882857),
#  'race_Black': np.float64(0.0037813850244042212),
#  'occupation_Handlers-cleaners': np.float64(0.003525699686049417),
#  'occupation_Adm-clerical': np.float64(0.0034794049553482885),
#  'occupation_Tech-support': np.float64(0.0034686134826471347),
#  'occupation_Transport-moving': np.float64(0.003094213072850469),
#  'workclass_State-gov': np.float64(0.002805059105747868),
#  'occupation_?': np.float64(0.0026836235977824273),
#  'native-country_Mexico': np.float64(0.0026627799226729824),
#  'race_Asian-Pac-Islander': np.float64(0.0025618344271905054),
#  'marital-status_Widowed': np.float64(0.0021067544964911682),
#  'native-country_?': np.float64(0.0020073290371720827),
#  'relationship_Other-relative': np.float64(0.0019110212889957496),
#  'occupation_Protective-serv': np.float64(0.00178242430467807),
#  'marital-status_Separated': np.float64(0.0016660491595066327),
#  'workclass_?': np.float64(0.0016611349744690299),
#  'native-country_Canada': np.float64(0.0012721720985889855),
#  'race_Amer-Indian-Eskimo': np.float64(0.0012481707148441245),
#  'marital-status_Married-spouse-absent': np.float64(0.0011061815279790432),
#  'native-country_Philippines': np.float64(0.0010603707548546913),
#  'native-country_India': np.float64(0.0010465969790792388),
#  'native-country_England': np.float64(0.0010340062057402886),
#  'native-country_Germany': np.float64(0.0008450058817124917),
#  'race_Other': np.float64(0.0007583576943573042),
#  'native-country_Italy': np.float64(0.00062141984754954),
#  'native-country_China': np.float64(0.0006067338888939432),
#  'native-country_Cuba': np.float64(0.0006057145268249498),
#  'native-country_South': np.float64(0.000589302784552463),
#  'native-country_Iran': np.float64(0.0004934014115831243),
#  'native-country_Poland': np.float64(0.00048811138598490366),
#  'native-country_Japan': np.float64(0.0004840229126576812),
#  'marital-status_Married-AF-spouse': np.float64(0.0004816864305624882),
#  'native-country_Greece': np.float64(0.00046954052408406326),
#  'native-country_Puerto-Rico': np.float64(0.0004561181066752912),
#  'native-country_Portugal': np.float64(0.0003877843969804357),
#  'native-country_Jamaica': np.float64(0.00037703513140569563),
#  'native-country_France': np.float64(0.0002953811480536863),
#  'native-country_Columbia': np.float64(0.00027190620996022307),
#  'native-country_Ireland': np.float64(0.0002705442921801032),
#  'native-country_Cambodia': np.float64(0.0002703752148883953),
#  'native-country_Yugoslavia': np.float64(0.0002512868629000632),
#  'native-country_Vietnam': np.float64(0.0002304944068839485),
#  'native-country_Dominican-Republic': np.float64(0.00022854811491159033),
#  'native-country_Taiwan': np.float64(0.00021403977994956708),
#  'native-country_El-Salvador': np.float64(0.00021136252521278262),
#  'occupation_Priv-house-serv': np.float64(0.00020196378930249542),
#  'native-country_Hong': np.float64(0.00017285114932631614),
#  'native-country_Trinadad&Tobago': np.float64(0.0001716971384551259),
#  'native-country_Haiti': np.float64(0.00016106740801429453),
#  'native-country_Nicaragua': np.float64(0.00012213391325234846),
#  'native-country_Laos': np.float64(0.00010670403787099571),
#  'native-country_Peru': np.float64(0.00010542804047095376),
#  'workclass_Without-pay': np.float64(0.00010424805608850513),
#  'native-country_Guatemala': np.float64(0.00010014411941066115),
#  'native-country_Thailand': np.float64(8.760397611234308e-05),
#  'native-country_Ecuador': np.float64(7.771344796547143e-05),
#  'native-country_Hungary': np.float64(7.667285230895678e-05),
#  'native-country_Scotland': np.float64(6.394631928940207e-05),
#  'occupation_Armed-Forces': np.float64(5.022018574361466e-05),
#  'native-country_Outlying-US(Guam-USVI-etc)': np.float64(1.8995509824895236e-05),
#  'native-country_Honduras': np.float64(1.045484045937454e-05),
#  'workclass_Never-worked': np.float64(9.725933929185e-07),
#  'native-country_Holand-Netherlands': np.float64(0.0)}
